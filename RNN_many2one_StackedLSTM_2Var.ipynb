# %% [markdown]
# <a href="https://colab.research.google.com/github/DaJaCruz/PhD/blob/main/RNN_many2one_StackedLSTM_2Var.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages

import tensorflow as tf
import pandas as pd # Pandas dataframe (very common in ML)
import numpy as np # import numpy to handle a lot of things!
from tensorflow.keras.models import Sequential
import random
from keras.layers import Bidirectional
from tensorflow.keras.layers import Dense, Dropout, LSTM#, CuDNNLSTM
import matplotlib.pyplot as plt # import plotting tools to create figures
from IPython.display import display, Math # to print with Latex math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from matplotlib import cm # to change colors of surface plots

# Uncomment line below if you want to enable live rotation of the surface plots.
#%matplotlib notebook

# %%
! sudo apt-get install texlive-latex-recommended 
! sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended  
! wget http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip 
! unzip type1cm.zip -d /tmp/type1cm 
! cd /tmp/type1cm/type1cm/ && sudo latex type1cm.ins
! sudo mkdir /usr/share/texmf/tex/latex/type1cm 
! sudo cp /tmp/type1cm/type1cm/type1cm.sty /usr/share/texmf/tex/latex/type1cm 
! sudo texhash 
# !apt install cm-super
# Out:
# Reading package lists... Done
# ^C

# %%
# Basic plotting tools needed in Python.

#%config InlineBackend.figure_format = "retina" # render higher resolution images in the notebook
#plt.style.use("seaborn") # style for plotting that comes from seaborn
FS = 26  # Font Size
plt.rcParams['axes.facecolor'] = (0.97, 0.97, 0.97)
plt.rcParams['figure.facecolor'] = (1, 1, 1)
plt.rcParams["font.family"] = "sans"
plt.rcParams["font.serif"] = "Times New Roman"
plt.rcParams['font.size'] = FS
params = {"ytick.color": (0, 0, 0),
          "xtick.color": (0, 0, 0),
          "grid.color": (.9, .9, .9),
          "text.color": (0, 0, 0),
          "axes.labelcolor": (0, 0, 0),
          "axes.edgecolor": (.15, .15, .15)#,
          #"text.usetex": True
          }
plt.rcParams.update(params)
linewidth=3.0

# %%
# import raw data
url = 'https://raw.githubusercontent.com/DaJaCruz/PhD/main/data91_all.csv'
df = pd.read_csv(url, delimiter=';')

# %%
# Split raw data in Input (X) and Output (Y) data
X_data_raw = df.loc[:,['Input_4','Input_5']].values
Y_data_raw = df.loc[:,['Output_1','Output_3']].values

# %%
_, idx = np.unique(Y_data_raw, axis=0, return_index=True)
Y_data_unique_sorted = Y_data_raw[np.sort(idx)]
Y_dat_unique = Y_data_unique_sorted[:, 0].reshape(-1, 1)
print(Y_dat_unique, Y_data_unique_sorted)

# %%
# Reshape data 
X_data_shaped = X_data_raw.reshape((91, 500, 2))
Y_data_shaped = Y_data_unique_sorted

# %%
#Select the number of cases used 
n_cases = 91
time_step_1 = 50
time_step_2 = 400
n_timesteps = time_step_2-time_step_1
total_n_points= n_cases*n_timesteps
X_data = X_data_shaped[:n_cases, time_step_1:time_step_2, :]
Y_data = Y_data_shaped[:n_cases, :]

# %%
#Reshape X_data and Y_data to Normalization operation
X_data_reshaped_norm=X_data.reshape(total_n_points, 2)
Y_data_reshaped_norm=Y_data

# %%
#
#Scale Inputs with a [-1,1] scaler
scaler_x = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_x = StandardScaler()
#
scaler_x.fit(X_data_reshaped_norm)# fit the scaler to the input data
#
X_data_scaled_shaped=scaler_x.transform(X_data_reshaped_norm) # scale the input data (the whole dataset)
#
#Scale Inputs with a [-1,1] scaler
scaler_y = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_y = StandardScaler()
#
scaler_y.fit(Y_data_reshaped_norm) # fit the scaler to the output data
Y_data_scaled_shaped=scaler_y.transform(Y_data_reshaped_norm) # scale the output data (the whole dataset)

# %%
# Reshape data 
X_data_scaled = X_data_scaled_shaped.reshape((n_cases, n_timesteps, 2))
Y_data_scaled = Y_data_scaled_shaped

# %%
print('X_data =', X_data.shape)
print('Y_data =', Y_data)
print('X_data_scaled =', X_data_scaled.shape)
print('Y_data_Scaled =', Y_data_scaled)

# %%
#Plots with normalized and Non-normalized inputs
fig_ANN, ((ax1_ANN, ax2_ANN), (ax3_ANN, ax4_ANN)) = plt.subplots(nrows=2, ncols=2, figsize=(30, 20))

#Case Studies to represent
Case_1 = 3
Case_2 = 4
Case_3 = 5

#Force Displacement Curves
ax1_ANN.plot(X_data[Case_1,:,0], X_data[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_2,:,0], X_data[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_3,:,0], X_data[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax1_ANN.set_xlabel('Time, $t$ [s]')
ax1_ANN.set_title('Non-normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([0, 10])
# ax1_ANN.set_xlim([0, 20])

# K-n Points
ax2_ANN.plot(Y_data[Case_1,1], Y_data[Case_1,0], 'o', markersize=10, color='blue') # show normalized training data
ax2_ANN.plot(Y_data[Case_2,1], Y_data[Case_2,0], 'o', markersize=10, color='gray') # show normalized training data
ax2_ANN.plot(Y_data[Case_3,1], Y_data[Case_3,0], 'o', markersize=10, color='red') # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Non-normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([200, 1800])
# ax2_ANN.set_xlim([0, 0.4])

ax3_ANN.plot(X_data_scaled[Case_1,:,0], X_data_scaled[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_2,:,0], X_data_scaled[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_3,:,0], X_data_scaled[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax3_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax3_ANN.set_xlabel('Time, $t$ [s]')
ax3_ANN.set_title('Normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax3_ANN.set_ylim([-1, 1])
# ax3_ANN.set_xlim([-1, 1])

# K-n Points
ax4_ANN.plot(Y_data[Case_1,1], Y_data_scaled[Case_1,0], 'o', markersize=10, color='blue') # show normalized training data
ax4_ANN.plot(Y_data[Case_2,1], Y_data_scaled[Case_2,0], 'o', markersize=10, color='gray') # show normalized training data
ax4_ANN.plot(Y_data[Case_3,1], Y_data_scaled[Case_3,0], 'o', markersize=10, color='red') # show normalized training data
ax4_ANN.set_ylabel('$K$')
ax4_ANN.set_xlabel('$n$')
ax4_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax4_ANN.set_ylim([-1.25, 1.25])
# ax4_ANN.set_xlim([-1.25, 1.25])


# Create figure with specified size
# fig_ANN.set_size_inches(22, 10)
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
print(Y_data_scaled[:,0,:])

# %%
# Divide datasets into train and test 

seed = random.randint(1, 50000) # set a random seed to replicate results
# seed = 15448
np.random.seed(seed)

testvalset_ratio = 0.4 # ratio of test set points from the dataset

X_train_scaled, X_test_scaled, Y_train_scaled, Y_test_scaled = train_test_split(X_data_scaled, Y_data_scaled,
                                                    test_size=testvalset_ratio,random_state=seed
                                                    )

print(seed)
# Out:
# 4699

# %%
#Plots with normalized and Non-normalized outputs
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)

ax1_ANN.plot(X_test_scaled[:,:,0], X_test_scaled[:,:,1], 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax1_ANN.plot(X_train_scaled[:,:,0], X_train_scaled[:,:,1], 'o', markersize=10, color='gray', label="training points") # show normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$')
ax1_ANN.set_xlabel('Punch Displacement, $y_p$')
ax1_ANN.set_title('Normalized input data')
# ax1_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([-1.25, 1.25])
# ax1_ANN.set_xlim([-1.25, 1.25])
# Create figure with specified size
fig_ANN.set_size_inches(22, 10)

# K-n Points
ax2_ANN.plot(Y_test_scaled[:,0], Y_test_scaled[:,1], 'o', markersize=10, color='black') # show normalized training data
ax2_ANN.plot(Y_train_scaled[:,0], Y_train_scaled[:,1], 'o', markersize=10, color='gray') # show normalized training data
# ax2_ANN.plot(cases, Y_test_scaled, 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([-1.25, 1.25])
# ax2_ANN.set_xlim([-1.25, 1.25])
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
# Build the Bidirectional LSTM model
model = Sequential()
model.add(Bidirectional(LSTM(n_timesteps, return_sequences=True, input_shape=(n_timesteps, 2), activation='tanh')))
# model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(50)))
# model.add(Dropout(0.2))
model.add(Dense(10, activation = "tanh"))
model.add(Dense(2, activation = "linear"))
model.compile()

# %%
# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error',
              optimizer=opt, metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train_scaled, Y_train_scaled, validation_data=(X_test_scaled, Y_test_scaled), epochs=2500)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# 2/2 [==============================] - 19s 2s/step - loss: 0.5827 - accuracy: 0.4444 - val_loss: 0.3860 - val_accuracy: 0.6486
# Epoch 2/2500
# 2/2 [==============================] - 0s 177ms/step - loss: 0.3900 - accuracy: 0.7037 - val_loss: 0.3739 - val_accuracy: 0.8919
# Epoch 3/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.3778 - accuracy: 0.7963 - val_loss: 0.2801 - val_accuracy: 1.0000
# Epoch 4/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2978 - accuracy: 0.8704 - val_loss: 0.2028 - val_accuracy: 0.9189
# Epoch 5/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.2790 - accuracy: 0.8704 - val_loss: 0.1905 - val_accuracy: 0.9189
# Epoch 6/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2699 - accuracy: 0.8148 - val_loss: 0.1918 - val_accuracy: 0.9189
# Epoch 7/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.2546 - accuracy: 0.8704 - val_loss: 0.2320 - val_accuracy: 0.9459
# Epoch 8/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2729 - accuracy: 0.8704 - val_loss: 0.2029 - val_accuracy: 1.0000
# Epoch 9/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.2528 - accuracy: 0.8889 - val_loss: 0.1973 - val_accuracy: 0.8919
# Epoch 10/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2513 - accuracy: 0.8148 - val_loss: 0.1880 - val_accuracy: 1.0000
# Epoch 11/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2453 - accuracy: 0.9630 - val_loss: 0.1999 - val_accuracy: 1.0000
# Epoch 12/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2495 - accuracy: 0.9074 - val_loss: 0.1966 - val_accuracy: 0.9189
# Epoch 13/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2505 - accuracy: 0.8519 - val_loss: 0.1837 - val_accuracy: 0.9730
# Epoch 14/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2381 - accuracy: 0.9259 - val_loss: 0.1911 - val_accuracy: 1.0000
# Epoch 15/2500
# 2/2 [==============================] - 0s 142ms/step - loss: 0.2420 - accuracy: 0.9074 - val_loss: 0.1852 - val_accuracy: 0.9730
# Epoch 16/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.2386 - accuracy: 0.9074 - val_loss: 0.1848 - val_accuracy: 0.9189
# Epoch 17/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2410 - accuracy: 0.8519 - val_loss: 0.1810 - val_accuracy: 0.9730
# Epoch 18/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.2364 - accuracy: 0.9074 - val_loss: 0.1817 - val_accuracy: 1.0000
# Epoch 19/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.2360 - accuracy: 0.8889 - val_loss: 0.1811 - val_accuracy: 1.0000
# Epoch 20/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.2389 - accuracy: 0.9259 - val_loss: 0.1788 - val_accuracy: 1.0000
# Epoch 21/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.2340 - accuracy: 0.9259 - val_loss: 0.1800 - val_accuracy: 1.0000
# Epoch 22/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2347 - accuracy: 0.9259 - val_loss: 0.1809 - val_accuracy: 0.9730
# Epoch 23/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.2349 - accuracy: 0.9074 - val_loss: 0.1805 - val_accuracy: 0.9730
# Epoch 24/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2337 - accuracy: 0.9259 - val_loss: 0.1797 - val_accuracy: 1.0000
# Epoch 25/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2320 - accuracy: 0.9259 - val_loss: 0.1825 - val_accuracy: 1.0000
# Epoch 26/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2324 - accuracy: 0.9259 - val_loss: 0.1851 - val_accuracy: 1.0000
# Epoch 27/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2318 - accuracy: 0.9259 - val_loss: 0.1838 - val_accuracy: 1.0000
# Epoch 28/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2318 - accuracy: 0.9259 - val_loss: 0.1838 - val_accuracy: 1.0000
# Epoch 29/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2319 - accuracy: 0.9259 - val_loss: 0.1848 - val_accuracy: 1.0000
# Epoch 30/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2307 - accuracy: 0.9444 - val_loss: 0.1845 - val_accuracy: 1.0000
# Epoch 31/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2296 - accuracy: 0.9074 - val_loss: 0.1829 - val_accuracy: 0.9730
# Epoch 32/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2285 - accuracy: 0.9074 - val_loss: 0.1870 - val_accuracy: 1.0000
# Epoch 33/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2312 - accuracy: 0.9259 - val_loss: 0.1822 - val_accuracy: 1.0000
# Epoch 34/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.2330 - accuracy: 0.9074 - val_loss: 0.1841 - val_accuracy: 1.0000
# Epoch 35/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2323 - accuracy: 0.9074 - val_loss: 0.1795 - val_accuracy: 1.0000
# Epoch 36/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2314 - accuracy: 0.9259 - val_loss: 0.1808 - val_accuracy: 0.9459
# Epoch 37/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.2344 - accuracy: 0.8889 - val_loss: 0.1756 - val_accuracy: 1.0000
# Epoch 38/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.2228 - accuracy: 0.9259 - val_loss: 0.1919 - val_accuracy: 1.0000
# Epoch 39/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2234 - accuracy: 0.9074 - val_loss: 0.1745 - val_accuracy: 1.0000
# Epoch 40/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.2245 - accuracy: 0.9259 - val_loss: 0.1794 - val_accuracy: 1.0000
# Epoch 41/2500
# 2/2 [==============================] - 0s 233ms/step - loss: 0.2237 - accuracy: 0.9259 - val_loss: 0.1784 - val_accuracy: 0.9730
# Epoch 42/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2177 - accuracy: 0.9074 - val_loss: 0.1895 - val_accuracy: 1.0000
# Epoch 43/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.2195 - accuracy: 0.9074 - val_loss: 0.2062 - val_accuracy: 0.9730
# Epoch 44/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2368 - accuracy: 0.9074 - val_loss: 0.1742 - val_accuracy: 0.9189
# Epoch 45/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2297 - accuracy: 0.8333 - val_loss: 0.1767 - val_accuracy: 0.9189
# Epoch 46/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.2141 - accuracy: 0.8704 - val_loss: 0.1867 - val_accuracy: 1.0000
# Epoch 47/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2316 - accuracy: 0.9259 - val_loss: 0.1730 - val_accuracy: 0.9730
# Epoch 48/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2214 - accuracy: 0.8519 - val_loss: 0.1869 - val_accuracy: 0.9730
# Epoch 49/2500
# 2/2 [==============================] - 0s 169ms/step - loss: 0.2178 - accuracy: 0.9074 - val_loss: 0.2208 - val_accuracy: 0.9730
# Epoch 50/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.2466 - accuracy: 0.9074 - val_loss: 0.1832 - val_accuracy: 1.0000
# Epoch 51/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2234 - accuracy: 0.9074 - val_loss: 0.1757 - val_accuracy: 0.9189
# Epoch 52/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2245 - accuracy: 0.8519 - val_loss: 0.1711 - val_accuracy: 1.0000
# Epoch 53/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.2125 - accuracy: 0.8889 - val_loss: 0.1887 - val_accuracy: 0.9730
# Epoch 54/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2267 - accuracy: 0.9259 - val_loss: 0.1780 - val_accuracy: 1.0000
# Epoch 55/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2006 - accuracy: 0.9259 - val_loss: 0.1814 - val_accuracy: 0.9730
# Epoch 56/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2286 - accuracy: 0.8889 - val_loss: 0.1762 - val_accuracy: 0.9189
# Epoch 57/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2024 - accuracy: 0.8889 - val_loss: 0.1804 - val_accuracy: 0.9730
# Epoch 58/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.2232 - accuracy: 0.9444 - val_loss: 0.1965 - val_accuracy: 0.9459
# Epoch 59/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2420 - accuracy: 0.8519 - val_loss: 0.1716 - val_accuracy: 1.0000
# Epoch 60/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2262 - accuracy: 0.8889 - val_loss: 0.1712 - val_accuracy: 0.9189
# Epoch 61/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2096 - accuracy: 0.8704 - val_loss: 0.2100 - val_accuracy: 0.9189
# Epoch 62/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2186 - accuracy: 0.8519 - val_loss: 0.1930 - val_accuracy: 0.9189
# Epoch 63/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2063 - accuracy: 0.8704 - val_loss: 0.1838 - val_accuracy: 1.0000
# Epoch 64/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2211 - accuracy: 0.9444 - val_loss: 0.1897 - val_accuracy: 1.0000
# Epoch 65/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2213 - accuracy: 0.9259 - val_loss: 0.1688 - val_accuracy: 1.0000
# Epoch 66/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1995 - accuracy: 0.9074 - val_loss: 0.1651 - val_accuracy: 1.0000
# Epoch 67/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2006 - accuracy: 0.9444 - val_loss: 0.1730 - val_accuracy: 1.0000
# Epoch 68/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1987 - accuracy: 0.9074 - val_loss: 0.1724 - val_accuracy: 0.9730
# Epoch 69/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2101 - accuracy: 0.8889 - val_loss: 0.1883 - val_accuracy: 0.9189
# Epoch 70/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.2257 - accuracy: 0.8704 - val_loss: 0.1689 - val_accuracy: 1.0000
# Epoch 71/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.2140 - accuracy: 0.9074 - val_loss: 0.1665 - val_accuracy: 1.0000
# Epoch 72/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1938 - accuracy: 0.9074 - val_loss: 0.2325 - val_accuracy: 0.9189
# Epoch 73/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2356 - accuracy: 0.8889 - val_loss: 0.1678 - val_accuracy: 1.0000
# Epoch 74/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2058 - accuracy: 0.9074 - val_loss: 0.2306 - val_accuracy: 0.9730
# Epoch 75/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2282 - accuracy: 0.9074 - val_loss: 0.1987 - val_accuracy: 1.0000
# Epoch 76/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.2090 - accuracy: 0.9259 - val_loss: 0.1823 - val_accuracy: 0.9459
# Epoch 77/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.2165 - accuracy: 0.8519 - val_loss: 0.1678 - val_accuracy: 0.9459
# Epoch 78/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1972 - accuracy: 0.8889 - val_loss: 0.1814 - val_accuracy: 1.0000
# Epoch 79/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1940 - accuracy: 0.9074 - val_loss: 0.1912 - val_accuracy: 1.0000
# Epoch 80/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1966 - accuracy: 0.9259 - val_loss: 0.1729 - val_accuracy: 1.0000
# Epoch 81/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1871 - accuracy: 0.9259 - val_loss: 0.1636 - val_accuracy: 1.0000
# Epoch 82/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.1872 - accuracy: 0.9074 - val_loss: 0.1650 - val_accuracy: 1.0000
# Epoch 83/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1831 - accuracy: 0.9259 - val_loss: 0.1681 - val_accuracy: 1.0000
# Epoch 84/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1767 - accuracy: 0.9074 - val_loss: 0.1773 - val_accuracy: 1.0000
# Epoch 85/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1863 - accuracy: 0.9074 - val_loss: 0.1751 - val_accuracy: 1.0000
# Epoch 86/2500
# 2/2 [==============================] - 0s 143ms/step - loss: 0.1856 - accuracy: 0.9074 - val_loss: 0.1702 - val_accuracy: 1.0000
# Epoch 87/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.1951 - accuracy: 0.9259 - val_loss: 0.1472 - val_accuracy: 0.9730
# Epoch 88/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.1835 - accuracy: 0.8704 - val_loss: 0.1839 - val_accuracy: 0.9189
# Epoch 89/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1889 - accuracy: 0.8519 - val_loss: 0.1776 - val_accuracy: 1.0000
# Epoch 90/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1882 - accuracy: 0.9259 - val_loss: 0.1567 - val_accuracy: 0.9730
# Epoch 91/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1651 - accuracy: 0.8889 - val_loss: 0.1707 - val_accuracy: 0.9730
# Epoch 92/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1744 - accuracy: 0.9074 - val_loss: 0.1610 - val_accuracy: 1.0000
# Epoch 93/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.1829 - accuracy: 0.9259 - val_loss: 0.1601 - val_accuracy: 1.0000
# Epoch 94/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1651 - accuracy: 0.9074 - val_loss: 0.1570 - val_accuracy: 1.0000
# Epoch 95/2500
# 2/2 [==============================] - 0s 255ms/step - loss: 0.1549 - accuracy: 0.9259 - val_loss: 0.1495 - val_accuracy: 0.9459
# Epoch 96/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1542 - accuracy: 0.8889 - val_loss: 0.1752 - val_accuracy: 1.0000
# Epoch 97/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1693 - accuracy: 0.9259 - val_loss: 0.2146 - val_accuracy: 0.9730
# Epoch 98/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2254 - accuracy: 0.9074 - val_loss: 0.2905 - val_accuracy: 1.0000
# Epoch 99/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.4326 - accuracy: 0.9074 - val_loss: 0.1455 - val_accuracy: 0.9730
# Epoch 100/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.2311 - accuracy: 0.8704 - val_loss: 0.2672 - val_accuracy: 1.0000
# Epoch 101/2500
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2304 - accuracy: 0.9259 - val_loss: 0.1952 - val_accuracy: 1.0000
# Epoch 102/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2234 - accuracy: 0.8889 - val_loss: 0.1739 - val_accuracy: 0.9189
# Epoch 103/2500
# 2/2 [==============================] - 0s 171ms/step - loss: 0.2066 - accuracy: 0.8519 - val_loss: 0.1628 - val_accuracy: 0.9459
# Epoch 104/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.2059 - accuracy: 0.8889 - val_loss: 0.2034 - val_accuracy: 1.0000
# Epoch 105/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.1947 - accuracy: 0.9444 - val_loss: 0.1928 - val_accuracy: 1.0000
# Epoch 106/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.2022 - accuracy: 0.8889 - val_loss: 0.1836 - val_accuracy: 1.0000
# Epoch 107/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1857 - accuracy: 0.9074 - val_loss: 0.1567 - val_accuracy: 1.0000
# Epoch 108/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1778 - accuracy: 0.9074 - val_loss: 0.1509 - val_accuracy: 0.9730
# Epoch 109/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1789 - accuracy: 0.9074 - val_loss: 0.1529 - val_accuracy: 1.0000
# Epoch 110/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1739 - accuracy: 0.9074 - val_loss: 0.1674 - val_accuracy: 1.0000
# Epoch 111/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1748 - accuracy: 0.9259 - val_loss: 0.1622 - val_accuracy: 1.0000
# Epoch 112/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1695 - accuracy: 0.9259 - val_loss: 0.1647 - val_accuracy: 1.0000
# Epoch 113/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1629 - accuracy: 0.9259 - val_loss: 0.1667 - val_accuracy: 1.0000
# Epoch 114/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1569 - accuracy: 0.9259 - val_loss: 0.1595 - val_accuracy: 1.0000
# Epoch 115/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1538 - accuracy: 0.9259 - val_loss: 0.1499 - val_accuracy: 1.0000
# Epoch 116/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1520 - accuracy: 0.9259 - val_loss: 0.1470 - val_accuracy: 1.0000
# Epoch 117/2500
# 2/2 [==============================] - 0s 144ms/step - loss: 0.1655 - accuracy: 0.9259 - val_loss: 0.1534 - val_accuracy: 1.0000
# Epoch 118/2500
# 2/2 [==============================] - 0s 145ms/step - loss: 0.1593 - accuracy: 0.8889 - val_loss: 0.1538 - val_accuracy: 1.0000
# Epoch 119/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1437 - accuracy: 0.9074 - val_loss: 0.1835 - val_accuracy: 1.0000
# Epoch 120/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1578 - accuracy: 0.9074 - val_loss: 0.1569 - val_accuracy: 1.0000
# Epoch 121/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1490 - accuracy: 0.9074 - val_loss: 0.1461 - val_accuracy: 1.0000
# Epoch 122/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1460 - accuracy: 0.9074 - val_loss: 0.1465 - val_accuracy: 0.9730
# Epoch 123/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1623 - accuracy: 0.9074 - val_loss: 0.1657 - val_accuracy: 0.9730
# Epoch 124/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1451 - accuracy: 0.9074 - val_loss: 0.1662 - val_accuracy: 1.0000
# Epoch 125/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1599 - accuracy: 0.9259 - val_loss: 0.1415 - val_accuracy: 1.0000
# Epoch 126/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1655 - accuracy: 0.9074 - val_loss: 0.1497 - val_accuracy: 1.0000
# Epoch 127/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1478 - accuracy: 0.9259 - val_loss: 0.1808 - val_accuracy: 0.9730
# Epoch 128/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1792 - accuracy: 0.8889 - val_loss: 0.1633 - val_accuracy: 1.0000
# Epoch 129/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1830 - accuracy: 0.9074 - val_loss: 0.1350 - val_accuracy: 0.9730
# Epoch 130/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1728 - accuracy: 0.9074 - val_loss: 0.1502 - val_accuracy: 1.0000
# Epoch 131/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1645 - accuracy: 0.9259 - val_loss: 0.1714 - val_accuracy: 1.0000
# Epoch 132/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1698 - accuracy: 0.9259 - val_loss: 0.1692 - val_accuracy: 1.0000
# Epoch 133/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1504 - accuracy: 0.9259 - val_loss: 0.1582 - val_accuracy: 1.0000
# Epoch 134/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.1295 - accuracy: 0.9259 - val_loss: 0.1688 - val_accuracy: 0.9730
# Epoch 135/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1512 - accuracy: 0.8889 - val_loss: 0.1440 - val_accuracy: 0.9459
# Epoch 136/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1318 - accuracy: 0.8704 - val_loss: 0.1518 - val_accuracy: 0.9459
# Epoch 137/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1241 - accuracy: 0.8704 - val_loss: 0.1520 - val_accuracy: 0.9730
# Epoch 138/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.1365 - accuracy: 0.9444 - val_loss: 0.1521 - val_accuracy: 1.0000
# Epoch 139/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1235 - accuracy: 0.9630 - val_loss: 0.1422 - val_accuracy: 1.0000
# Epoch 140/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1158 - accuracy: 0.9630 - val_loss: 0.1484 - val_accuracy: 1.0000
# Epoch 141/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1314 - accuracy: 0.9259 - val_loss: 0.1513 - val_accuracy: 0.9730
# Epoch 142/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1141 - accuracy: 0.9074 - val_loss: 0.1355 - val_accuracy: 0.9730
# Epoch 143/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1222 - accuracy: 0.9074 - val_loss: 0.1314 - val_accuracy: 0.9730
# Epoch 144/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1218 - accuracy: 0.9074 - val_loss: 0.1395 - val_accuracy: 0.9730
# Epoch 145/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1258 - accuracy: 0.9074 - val_loss: 0.1397 - val_accuracy: 1.0000
# Epoch 146/2500
# 2/2 [==============================] - 0s 146ms/step - loss: 0.1180 - accuracy: 0.9259 - val_loss: 0.1364 - val_accuracy: 1.0000
# Epoch 147/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.1035 - accuracy: 0.9444 - val_loss: 0.1439 - val_accuracy: 0.9730
# Epoch 148/2500
# 2/2 [==============================] - 0s 167ms/step - loss: 0.1198 - accuracy: 0.9074 - val_loss: 0.1318 - val_accuracy: 0.9730
# Epoch 149/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.1068 - accuracy: 0.8889 - val_loss: 0.1317 - val_accuracy: 0.9459
# Epoch 150/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1074 - accuracy: 0.8889 - val_loss: 0.1263 - val_accuracy: 0.9730
# Epoch 151/2500
# 2/2 [==============================] - 0s 242ms/step - loss: 0.1012 - accuracy: 0.9074 - val_loss: 0.1654 - val_accuracy: 0.9730
# Epoch 152/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0993 - accuracy: 0.9074 - val_loss: 0.1275 - val_accuracy: 0.9730
# Epoch 153/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0976 - accuracy: 0.9074 - val_loss: 0.1233 - val_accuracy: 0.9730
# Epoch 154/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0886 - accuracy: 0.9074 - val_loss: 0.1545 - val_accuracy: 0.9730
# Epoch 155/2500
# 2/2 [==============================] - 0s 248ms/step - loss: 0.1002 - accuracy: 0.8889 - val_loss: 0.1468 - val_accuracy: 0.9459
# Epoch 156/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1148 - accuracy: 0.9074 - val_loss: 0.1537 - val_accuracy: 0.9730
# Epoch 157/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1256 - accuracy: 0.9074 - val_loss: 0.1646 - val_accuracy: 1.0000
# Epoch 158/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1299 - accuracy: 0.9074 - val_loss: 0.1605 - val_accuracy: 1.0000
# Epoch 159/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.1359 - accuracy: 0.9074 - val_loss: 0.1791 - val_accuracy: 0.9730
# Epoch 160/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1344 - accuracy: 0.8889 - val_loss: 0.1776 - val_accuracy: 0.9459
# Epoch 161/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1786 - accuracy: 0.8889 - val_loss: 0.2204 - val_accuracy: 1.0000
# Epoch 162/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1404 - accuracy: 0.9259 - val_loss: 0.1696 - val_accuracy: 1.0000
# Epoch 163/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1620 - accuracy: 0.9259 - val_loss: 0.1596 - val_accuracy: 1.0000
# Epoch 164/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1827 - accuracy: 0.9259 - val_loss: 0.2128 - val_accuracy: 0.9730
# Epoch 165/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.2080 - accuracy: 0.8889 - val_loss: 0.1384 - val_accuracy: 0.9459
# Epoch 166/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.1453 - accuracy: 0.8704 - val_loss: 0.1999 - val_accuracy: 0.9730
# Epoch 167/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1582 - accuracy: 0.8889 - val_loss: 0.1920 - val_accuracy: 0.9730
# Epoch 168/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.2427 - accuracy: 0.8889 - val_loss: 0.1603 - val_accuracy: 1.0000
# Epoch 169/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1230 - accuracy: 0.9074 - val_loss: 0.1804 - val_accuracy: 1.0000
# Epoch 170/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1669 - accuracy: 0.9074 - val_loss: 0.1550 - val_accuracy: 1.0000
# Epoch 171/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.1722 - accuracy: 0.9074 - val_loss: 0.1478 - val_accuracy: 1.0000
# Epoch 172/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.1316 - accuracy: 0.9259 - val_loss: 0.1822 - val_accuracy: 1.0000
# Epoch 173/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1480 - accuracy: 0.9074 - val_loss: 0.1408 - val_accuracy: 1.0000
# Epoch 174/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1254 - accuracy: 0.9630 - val_loss: 0.1350 - val_accuracy: 1.0000
# Epoch 175/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1290 - accuracy: 0.9259 - val_loss: 0.1497 - val_accuracy: 1.0000
# Epoch 176/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1258 - accuracy: 0.9444 - val_loss: 0.1594 - val_accuracy: 1.0000
# Epoch 177/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1199 - accuracy: 0.9444 - val_loss: 0.1684 - val_accuracy: 1.0000
# Epoch 178/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1136 - accuracy: 0.9259 - val_loss: 0.1401 - val_accuracy: 1.0000
# Epoch 179/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1329 - accuracy: 0.9259 - val_loss: 0.1361 - val_accuracy: 0.9730
# Epoch 180/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1093 - accuracy: 0.9259 - val_loss: 0.1503 - val_accuracy: 0.9730
# Epoch 181/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1376 - accuracy: 0.8889 - val_loss: 0.1552 - val_accuracy: 1.0000
# Epoch 182/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1168 - accuracy: 0.9259 - val_loss: 0.1623 - val_accuracy: 1.0000
# Epoch 183/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.1169 - accuracy: 0.9444 - val_loss: 0.1396 - val_accuracy: 1.0000
# Epoch 184/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.1687 - accuracy: 0.9074 - val_loss: 0.1274 - val_accuracy: 1.0000
# Epoch 185/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1244 - accuracy: 0.9259 - val_loss: 0.1792 - val_accuracy: 1.0000
# Epoch 186/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1474 - accuracy: 0.9444 - val_loss: 0.1561 - val_accuracy: 0.9730
# Epoch 187/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.1708 - accuracy: 0.9074 - val_loss: 0.1648 - val_accuracy: 0.9730
# Epoch 188/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1271 - accuracy: 0.8889 - val_loss: 0.1771 - val_accuracy: 1.0000
# Epoch 189/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1808 - accuracy: 0.9444 - val_loss: 0.1369 - val_accuracy: 0.9730
# Epoch 190/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1003 - accuracy: 0.9074 - val_loss: 0.1843 - val_accuracy: 0.9730
# Epoch 191/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1345 - accuracy: 0.8889 - val_loss: 0.1482 - val_accuracy: 0.9730
# Epoch 192/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1052 - accuracy: 0.8889 - val_loss: 0.1463 - val_accuracy: 0.9730
# Epoch 193/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1115 - accuracy: 0.9074 - val_loss: 0.1292 - val_accuracy: 0.9730
# Epoch 194/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1175 - accuracy: 0.9074 - val_loss: 0.1462 - val_accuracy: 1.0000
# Epoch 195/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0951 - accuracy: 0.9074 - val_loss: 0.1679 - val_accuracy: 1.0000
# Epoch 196/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1215 - accuracy: 0.9444 - val_loss: 0.1459 - val_accuracy: 1.0000
# Epoch 197/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0943 - accuracy: 0.9074 - val_loss: 0.1325 - val_accuracy: 0.9730
# Epoch 198/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1149 - accuracy: 0.9074 - val_loss: 0.1321 - val_accuracy: 0.9730
# Epoch 199/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0883 - accuracy: 0.9074 - val_loss: 0.1521 - val_accuracy: 0.9730
# Epoch 200/2500
# 2/2 [==============================] - 0s 255ms/step - loss: 0.1011 - accuracy: 0.8889 - val_loss: 0.1458 - val_accuracy: 0.9730
# Epoch 201/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0935 - accuracy: 0.8889 - val_loss: 0.1237 - val_accuracy: 0.9730
# Epoch 202/2500
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0913 - accuracy: 0.9074 - val_loss: 0.1319 - val_accuracy: 0.9730
# Epoch 203/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0864 - accuracy: 0.9074 - val_loss: 0.1463 - val_accuracy: 0.9730
# Epoch 204/2500
# 2/2 [==============================] - 0s 178ms/step - loss: 0.0824 - accuracy: 0.9074 - val_loss: 0.1221 - val_accuracy: 0.9730
# Epoch 205/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0837 - accuracy: 0.9074 - val_loss: 0.1219 - val_accuracy: 0.9730
# Epoch 206/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0786 - accuracy: 0.9074 - val_loss: 0.1508 - val_accuracy: 0.9730
# Epoch 207/2500
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0827 - accuracy: 0.9074 - val_loss: 0.1257 - val_accuracy: 0.9730
# Epoch 208/2500
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0726 - accuracy: 0.9074 - val_loss: 0.1201 - val_accuracy: 0.9730
# Epoch 209/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0757 - accuracy: 0.9074 - val_loss: 0.1388 - val_accuracy: 0.9459
# Epoch 210/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0747 - accuracy: 0.8889 - val_loss: 0.1390 - val_accuracy: 0.9459
# Epoch 211/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0749 - accuracy: 0.8889 - val_loss: 0.1143 - val_accuracy: 0.9730
# Epoch 212/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0728 - accuracy: 0.8889 - val_loss: 0.1195 - val_accuracy: 0.9730
# Epoch 213/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0690 - accuracy: 0.9074 - val_loss: 0.1385 - val_accuracy: 0.9730
# Epoch 214/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0692 - accuracy: 0.9074 - val_loss: 0.1131 - val_accuracy: 0.9459
# Epoch 215/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0709 - accuracy: 0.8889 - val_loss: 0.1313 - val_accuracy: 0.9730
# Epoch 216/2500
# 2/2 [==============================] - 0s 292ms/step - loss: 0.0696 - accuracy: 0.8889 - val_loss: 0.1286 - val_accuracy: 0.9730
# Epoch 217/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0655 - accuracy: 0.9074 - val_loss: 0.1082 - val_accuracy: 0.9730
# Epoch 218/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0805 - accuracy: 0.9074 - val_loss: 0.1367 - val_accuracy: 0.9730
# Epoch 219/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0777 - accuracy: 0.8889 - val_loss: 0.1032 - val_accuracy: 0.9730
# Epoch 220/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0702 - accuracy: 0.9074 - val_loss: 0.1089 - val_accuracy: 0.9730
# Epoch 221/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0728 - accuracy: 0.9074 - val_loss: 0.1053 - val_accuracy: 0.9730
# Epoch 222/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0662 - accuracy: 0.9074 - val_loss: 0.1011 - val_accuracy: 0.9730
# Epoch 223/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0741 - accuracy: 0.9074 - val_loss: 0.1942 - val_accuracy: 1.0000
# Epoch 224/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.1269 - accuracy: 0.9074 - val_loss: 0.1524 - val_accuracy: 1.0000
# Epoch 225/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1191 - accuracy: 0.9444 - val_loss: 0.1474 - val_accuracy: 1.0000
# Epoch 226/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1269 - accuracy: 0.9259 - val_loss: 0.1704 - val_accuracy: 1.0000
# Epoch 227/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1260 - accuracy: 0.9074 - val_loss: 0.1697 - val_accuracy: 0.9730
# Epoch 228/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0946 - accuracy: 0.8889 - val_loss: 0.1101 - val_accuracy: 0.9730
# Epoch 229/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1040 - accuracy: 0.9074 - val_loss: 0.1440 - val_accuracy: 1.0000
# Epoch 230/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1100 - accuracy: 0.9074 - val_loss: 0.2129 - val_accuracy: 1.0000
# Epoch 231/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1488 - accuracy: 0.9074 - val_loss: 0.1377 - val_accuracy: 1.0000
# Epoch 232/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1229 - accuracy: 0.9074 - val_loss: 0.1220 - val_accuracy: 1.0000
# Epoch 233/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.1257 - accuracy: 0.9074 - val_loss: 0.1240 - val_accuracy: 0.9730
# Epoch 234/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0955 - accuracy: 0.9074 - val_loss: 0.1733 - val_accuracy: 1.0000
# Epoch 235/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1256 - accuracy: 0.9074 - val_loss: 0.1714 - val_accuracy: 1.0000
# Epoch 236/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1091 - accuracy: 0.8889 - val_loss: 0.1308 - val_accuracy: 0.9730
# Epoch 237/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0703 - accuracy: 0.8889 - val_loss: 0.1394 - val_accuracy: 1.0000
# Epoch 238/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1177 - accuracy: 0.9259 - val_loss: 0.1156 - val_accuracy: 0.9730
# Epoch 239/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0938 - accuracy: 0.8889 - val_loss: 0.1597 - val_accuracy: 1.0000
# Epoch 240/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1101 - accuracy: 0.9259 - val_loss: 0.1452 - val_accuracy: 1.0000
# Epoch 241/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0986 - accuracy: 0.9444 - val_loss: 0.1150 - val_accuracy: 1.0000
# Epoch 242/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0978 - accuracy: 0.9074 - val_loss: 0.1191 - val_accuracy: 1.0000
# Epoch 243/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0828 - accuracy: 0.9259 - val_loss: 0.1225 - val_accuracy: 1.0000
# Epoch 244/2500
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0767 - accuracy: 0.9074 - val_loss: 0.1361 - val_accuracy: 1.0000
# Epoch 245/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0781 - accuracy: 0.9259 - val_loss: 0.1172 - val_accuracy: 1.0000
# Epoch 246/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0781 - accuracy: 0.9259 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 247/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0862 - accuracy: 0.9259 - val_loss: 0.1164 - val_accuracy: 1.0000
# Epoch 248/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0772 - accuracy: 0.9444 - val_loss: 0.1212 - val_accuracy: 1.0000
# Epoch 249/2500
# 2/2 [==============================] - 0s 149ms/step - loss: 0.0709 - accuracy: 0.9444 - val_loss: 0.1281 - val_accuracy: 1.0000
# Epoch 250/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0782 - accuracy: 0.9259 - val_loss: 0.1373 - val_accuracy: 1.0000
# Epoch 251/2500
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0893 - accuracy: 0.9259 - val_loss: 0.1151 - val_accuracy: 1.0000
# Epoch 252/2500
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0848 - accuracy: 0.9074 - val_loss: 0.1101 - val_accuracy: 1.0000
# Epoch 253/2500
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0718 - accuracy: 0.9074 - val_loss: 0.1134 - val_accuracy: 1.0000
# Epoch 254/2500
# 2/2 [==============================] - 0s 174ms/step - loss: 0.0685 - accuracy: 0.9074 - val_loss: 0.1365 - val_accuracy: 0.9730
# Epoch 255/2500
# 2/2 [==============================] - 0s 180ms/step - loss: 0.0836 - accuracy: 0.9074 - val_loss: 0.1269 - val_accuracy: 1.0000
# Epoch 256/2500
# 2/2 [==============================] - 0s 183ms/step - loss: 0.0752 - accuracy: 0.9074 - val_loss: 0.1034 - val_accuracy: 0.9730
# Epoch 257/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0856 - accuracy: 0.8889 - val_loss: 0.1047 - val_accuracy: 0.9730
# Epoch 258/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0861 - accuracy: 0.9074 - val_loss: 0.1193 - val_accuracy: 1.0000
# Epoch 259/2500
# 2/2 [==============================] - 0s 170ms/step - loss: 0.0780 - accuracy: 0.9259 - val_loss: 0.1322 - val_accuracy: 1.0000
# Epoch 260/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0838 - accuracy: 0.9074 - val_loss: 0.1220 - val_accuracy: 1.0000
# Epoch 261/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0843 - accuracy: 0.9444 - val_loss: 0.1122 - val_accuracy: 1.0000
# Epoch 262/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0694 - accuracy: 0.9074 - val_loss: 0.1174 - val_accuracy: 1.0000
# Epoch 263/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0678 - accuracy: 0.9074 - val_loss: 0.1089 - val_accuracy: 1.0000
# Epoch 264/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0641 - accuracy: 0.9074 - val_loss: 0.1054 - val_accuracy: 0.9730
# Epoch 265/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0652 - accuracy: 0.9074 - val_loss: 0.1222 - val_accuracy: 1.0000
# Epoch 266/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0696 - accuracy: 0.9074 - val_loss: 0.1002 - val_accuracy: 1.0000
# Epoch 267/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0592 - accuracy: 0.9074 - val_loss: 0.1057 - val_accuracy: 1.0000
# Epoch 268/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0684 - accuracy: 0.9074 - val_loss: 0.1203 - val_accuracy: 1.0000
# Epoch 269/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0738 - accuracy: 0.9074 - val_loss: 0.0962 - val_accuracy: 1.0000
# Epoch 270/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0550 - accuracy: 0.9074 - val_loss: 0.0988 - val_accuracy: 0.9730
# Epoch 271/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0606 - accuracy: 0.8889 - val_loss: 0.1218 - val_accuracy: 0.9459
# Epoch 272/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0672 - accuracy: 0.8889 - val_loss: 0.0890 - val_accuracy: 0.9730
# Epoch 273/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0536 - accuracy: 0.8889 - val_loss: 0.0835 - val_accuracy: 0.9730
# Epoch 274/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0562 - accuracy: 0.8889 - val_loss: 0.1332 - val_accuracy: 1.0000
# Epoch 275/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0738 - accuracy: 0.9444 - val_loss: 0.0835 - val_accuracy: 1.0000
# Epoch 276/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0561 - accuracy: 0.9630 - val_loss: 0.0962 - val_accuracy: 1.0000
# Epoch 277/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0570 - accuracy: 0.9259 - val_loss: 0.0887 - val_accuracy: 1.0000
# Epoch 278/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0805 - accuracy: 0.9259 - val_loss: 0.1282 - val_accuracy: 1.0000
# Epoch 279/2500
# 2/2 [==============================] - 0s 147ms/step - loss: 0.0952 - accuracy: 0.9630 - val_loss: 0.1097 - val_accuracy: 1.0000
# Epoch 280/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0684 - accuracy: 0.9630 - val_loss: 0.1222 - val_accuracy: 1.0000
# Epoch 281/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0934 - accuracy: 0.9630 - val_loss: 0.1265 - val_accuracy: 1.0000
# Epoch 282/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0824 - accuracy: 0.9074 - val_loss: 0.1590 - val_accuracy: 0.9730
# Epoch 283/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0771 - accuracy: 0.8889 - val_loss: 0.1031 - val_accuracy: 0.9730
# Epoch 284/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1119 - accuracy: 0.8889 - val_loss: 0.0965 - val_accuracy: 0.9730
# Epoch 285/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0809 - accuracy: 0.9074 - val_loss: 0.1045 - val_accuracy: 1.0000
# Epoch 286/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0819 - accuracy: 0.9074 - val_loss: 0.1549 - val_accuracy: 1.0000
# Epoch 287/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1190 - accuracy: 0.9074 - val_loss: 0.1270 - val_accuracy: 1.0000
# Epoch 288/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.1466 - accuracy: 0.9259 - val_loss: 0.1031 - val_accuracy: 0.9730
# Epoch 289/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.1080 - accuracy: 0.9074 - val_loss: 0.2033 - val_accuracy: 1.0000
# Epoch 290/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.1168 - accuracy: 0.9259 - val_loss: 0.1092 - val_accuracy: 0.9730
# Epoch 291/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0852 - accuracy: 0.8889 - val_loss: 0.1119 - val_accuracy: 0.9730
# Epoch 292/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0815 - accuracy: 0.9074 - val_loss: 0.1400 - val_accuracy: 1.0000
# Epoch 293/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0726 - accuracy: 0.9444 - val_loss: 0.1247 - val_accuracy: 1.0000
# Epoch 294/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0757 - accuracy: 0.9259 - val_loss: 0.1026 - val_accuracy: 1.0000
# Epoch 295/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0720 - accuracy: 0.9259 - val_loss: 0.1139 - val_accuracy: 0.9730
# Epoch 296/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0858 - accuracy: 0.8889 - val_loss: 0.1389 - val_accuracy: 1.0000
# Epoch 297/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0968 - accuracy: 0.9444 - val_loss: 0.1065 - val_accuracy: 1.0000
# Epoch 298/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0776 - accuracy: 0.9259 - val_loss: 0.1044 - val_accuracy: 1.0000
# Epoch 299/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0681 - accuracy: 0.9444 - val_loss: 0.1359 - val_accuracy: 1.0000
# Epoch 300/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0903 - accuracy: 0.9444 - val_loss: 0.1440 - val_accuracy: 1.0000
# Epoch 301/2500
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0930 - accuracy: 0.9259 - val_loss: 0.1303 - val_accuracy: 1.0000
# Epoch 302/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0766 - accuracy: 0.9259 - val_loss: 0.1084 - val_accuracy: 1.0000
# Epoch 303/2500
# 2/2 [==============================] - 0s 264ms/step - loss: 0.0732 - accuracy: 0.9074 - val_loss: 0.1147 - val_accuracy: 1.0000
# Epoch 304/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0648 - accuracy: 0.9444 - val_loss: 0.1276 - val_accuracy: 1.0000
# Epoch 305/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0745 - accuracy: 0.9074 - val_loss: 0.1009 - val_accuracy: 1.0000
# Epoch 306/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0622 - accuracy: 0.9259 - val_loss: 0.1007 - val_accuracy: 1.0000
# Epoch 307/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0609 - accuracy: 0.9259 - val_loss: 0.1236 - val_accuracy: 1.0000
# Epoch 308/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0642 - accuracy: 0.9259 - val_loss: 0.1171 - val_accuracy: 1.0000
# Epoch 309/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0580 - accuracy: 0.9444 - val_loss: 0.1010 - val_accuracy: 1.0000
# Epoch 310/2500
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0618 - accuracy: 0.9259 - val_loss: 0.1037 - val_accuracy: 1.0000
# Epoch 311/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0644 - accuracy: 0.9444 - val_loss: 0.1163 - val_accuracy: 1.0000
# Epoch 312/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0638 - accuracy: 0.9259 - val_loss: 0.0931 - val_accuracy: 1.0000
# Epoch 313/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0565 - accuracy: 0.9259 - val_loss: 0.0992 - val_accuracy: 1.0000
# Epoch 314/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0582 - accuracy: 0.8889 - val_loss: 0.1176 - val_accuracy: 0.9730
# Epoch 315/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0662 - accuracy: 0.8889 - val_loss: 0.1254 - val_accuracy: 1.0000
# Epoch 316/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0685 - accuracy: 0.9259 - val_loss: 0.0995 - val_accuracy: 1.0000
# Epoch 317/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0625 - accuracy: 0.9074 - val_loss: 0.0963 - val_accuracy: 1.0000
# Epoch 318/2500
# 2/2 [==============================] - 0s 148ms/step - loss: 0.0592 - accuracy: 0.9259 - val_loss: 0.1064 - val_accuracy: 1.0000
# Epoch 319/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0677 - accuracy: 0.9074 - val_loss: 0.0948 - val_accuracy: 1.0000
# Epoch 320/2500
# 2/2 [==============================] - 0s 150ms/step - loss: 0.0664 - accuracy: 0.9259 - val_loss: 0.0919 - val_accuracy: 0.9730
# Epoch 321/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0617 - accuracy: 0.8889 - val_loss: 0.1261 - val_accuracy: 1.0000
# Epoch 322/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0708 - accuracy: 0.9259 - val_loss: 0.0857 - val_accuracy: 1.0000
# Epoch 323/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0553 - accuracy: 0.9259 - val_loss: 0.0932 - val_accuracy: 1.0000
# Epoch 324/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0617 - accuracy: 0.9259 - val_loss: 0.1272 - val_accuracy: 1.0000
# Epoch 325/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0702 - accuracy: 0.9444 - val_loss: 0.0978 - val_accuracy: 1.0000
# Epoch 326/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0551 - accuracy: 0.9259 - val_loss: 0.0970 - val_accuracy: 1.0000
# Epoch 327/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0567 - accuracy: 0.9444 - val_loss: 0.1208 - val_accuracy: 1.0000
# Epoch 328/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0783 - accuracy: 0.9444 - val_loss: 0.1244 - val_accuracy: 1.0000
# Epoch 329/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0626 - accuracy: 0.9259 - val_loss: 0.0988 - val_accuracy: 1.0000
# Epoch 330/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0777 - accuracy: 0.9259 - val_loss: 0.1175 - val_accuracy: 1.0000
# Epoch 331/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0658 - accuracy: 0.9259 - val_loss: 0.1071 - val_accuracy: 1.0000
# Epoch 332/2500
# 2/2 [==============================] - 0s 155ms/step - loss: 0.0592 - accuracy: 0.9259 - val_loss: 0.0911 - val_accuracy: 1.0000
# Epoch 333/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0761 - accuracy: 0.9074 - val_loss: 0.0956 - val_accuracy: 1.0000
# Epoch 334/2500
# ...
# Epoch 2391/2500
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0162 - accuracy: 0.9444 - val_loss: 0.0741 - val_accuracy: 0.9730
# Epoch 2392/2500
# 2/2 [==============================] - 0s 196ms/step - loss: 0.0209 - accuracy: 0.9259 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 2393/2500
# 2/2 [==============================] - 0s 278ms/step - loss: 0.0156 - accuracy: 0.9630 - val_loss: 0.0486 - val_accuracy: 1.0000
# Epoch 2394/2500
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0094 - accuracy: 0.9444 - val_loss: 0.0482 - val_accuracy: 1.0000
# Epoch 2395/2500
# 2/2 [==============================] - 0s 248ms/step - loss: 0.0098 - accuracy: 0.9259 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 2396/2500
# 2/2 [==============================] - 0s 273ms/step - loss: 0.0083 - accuracy: 0.9444 - val_loss: 0.0566 - val_accuracy: 0.9730
# Epoch 2397/2500
# 2/2 [==============================] - 0s 153ms/step - loss: 0.0128 - accuracy: 0.9444 - val_loss: 0.0462 - val_accuracy: 1.0000
# Epoch 2398/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0104 - accuracy: 0.9630 - val_loss: 0.0568 - val_accuracy: 1.0000
# Epoch 2399/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0085 - accuracy: 0.9444 - val_loss: 0.0516 - val_accuracy: 1.0000
# Epoch 2400/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0074 - accuracy: 0.9630 - val_loss: 0.0479 - val_accuracy: 1.0000
# Epoch 2401/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0054 - accuracy: 0.9259 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 2402/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0074 - accuracy: 0.9444 - val_loss: 0.0470 - val_accuracy: 1.0000
# Epoch 2403/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0080 - accuracy: 0.9444 - val_loss: 0.0546 - val_accuracy: 0.9730
# Epoch 2404/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0075 - accuracy: 0.9444 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 2405/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0059 - accuracy: 0.9259 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 2406/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0064 - accuracy: 0.9444 - val_loss: 0.0596 - val_accuracy: 1.0000
# Epoch 2407/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0052 - accuracy: 0.9444 - val_loss: 0.0515 - val_accuracy: 1.0000
# Epoch 2408/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0075 - accuracy: 0.9259 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 2409/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0056 - accuracy: 0.9444 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 2410/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0043 - accuracy: 0.9259 - val_loss: 0.0527 - val_accuracy: 1.0000
# Epoch 2411/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0040 - accuracy: 0.9444 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 2412/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0041 - accuracy: 0.9444 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 2413/2500
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0049 - accuracy: 0.9444 - val_loss: 0.0512 - val_accuracy: 1.0000
# Epoch 2414/2500
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0037 - accuracy: 0.9259 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 2415/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0049 - accuracy: 0.9259 - val_loss: 0.0533 - val_accuracy: 1.0000
# Epoch 2416/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0032 - accuracy: 0.9444 - val_loss: 0.0581 - val_accuracy: 1.0000
# Epoch 2417/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0039 - accuracy: 0.9259 - val_loss: 0.0488 - val_accuracy: 1.0000
# Epoch 2418/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0040 - accuracy: 0.9444 - val_loss: 0.0508 - val_accuracy: 1.0000
# Epoch 2419/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0045 - accuracy: 0.9259 - val_loss: 0.0476 - val_accuracy: 1.0000
# Epoch 2420/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0499 - val_accuracy: 1.0000
# Epoch 2421/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0041 - accuracy: 0.9630 - val_loss: 0.0583 - val_accuracy: 1.0000
# Epoch 2422/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0048 - accuracy: 0.9444 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 2423/2500
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0037 - accuracy: 0.9259 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 2424/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0041 - accuracy: 0.9444 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 2425/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0049 - accuracy: 0.9444 - val_loss: 0.0542 - val_accuracy: 1.0000
# Epoch 2426/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0050 - accuracy: 0.9444 - val_loss: 0.0480 - val_accuracy: 1.0000
# Epoch 2427/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0042 - accuracy: 0.9444 - val_loss: 0.0579 - val_accuracy: 1.0000
# Epoch 2428/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0555 - val_accuracy: 1.0000
# Epoch 2429/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0036 - accuracy: 0.9444 - val_loss: 0.0528 - val_accuracy: 1.0000
# Epoch 2430/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0049 - accuracy: 0.9444 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 2431/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0056 - accuracy: 0.9444 - val_loss: 0.0622 - val_accuracy: 1.0000
# Epoch 2432/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0045 - accuracy: 0.9259 - val_loss: 0.0517 - val_accuracy: 1.0000
# Epoch 2433/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0037 - accuracy: 0.9630 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 2434/2500
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0034 - accuracy: 0.9444 - val_loss: 0.0600 - val_accuracy: 1.0000
# Epoch 2435/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0039 - accuracy: 0.9259 - val_loss: 0.0490 - val_accuracy: 1.0000
# Epoch 2436/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0028 - accuracy: 0.9444 - val_loss: 0.0487 - val_accuracy: 1.0000
# Epoch 2437/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0026 - accuracy: 0.9444 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 2438/2500
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0025 - accuracy: 0.9444 - val_loss: 0.0529 - val_accuracy: 1.0000
# Epoch 2439/2500
# 2/2 [==============================] - 0s 206ms/step - loss: 0.0027 - accuracy: 0.9444 - val_loss: 0.0634 - val_accuracy: 1.0000
# Epoch 2440/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0026 - accuracy: 0.9444 - val_loss: 0.0589 - val_accuracy: 1.0000
# Epoch 2441/2500
# 2/2 [==============================] - 0s 224ms/step - loss: 0.0030 - accuracy: 0.9444 - val_loss: 0.0620 - val_accuracy: 1.0000
# Epoch 2442/2500
# 2/2 [==============================] - 0s 190ms/step - loss: 0.0029 - accuracy: 0.9444 - val_loss: 0.0639 - val_accuracy: 1.0000
# Epoch 2443/2500
# 2/2 [==============================] - 0s 249ms/step - loss: 0.0030 - accuracy: 0.9444 - val_loss: 0.0608 - val_accuracy: 1.0000
# Epoch 2444/2500
# 2/2 [==============================] - 0s 269ms/step - loss: 0.0040 - accuracy: 0.9630 - val_loss: 0.0669 - val_accuracy: 1.0000
# Epoch 2445/2500
# 2/2 [==============================] - 0s 255ms/step - loss: 0.0044 - accuracy: 0.9444 - val_loss: 0.0656 - val_accuracy: 1.0000
# Epoch 2446/2500
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0055 - accuracy: 0.9259 - val_loss: 0.0558 - val_accuracy: 0.9730
# Epoch 2447/2500
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0095 - accuracy: 0.9444 - val_loss: 0.0512 - val_accuracy: 1.0000
# Epoch 2448/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0055 - accuracy: 0.9444 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 2449/2500
# 2/2 [==============================] - 0s 156ms/step - loss: 0.0072 - accuracy: 0.9444 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 2450/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0041 - accuracy: 0.9259 - val_loss: 0.0460 - val_accuracy: 0.9730
# Epoch 2451/2500
# 2/2 [==============================] - 0s 151ms/step - loss: 0.0075 - accuracy: 0.9259 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 2452/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0046 - accuracy: 0.9444 - val_loss: 0.0459 - val_accuracy: 1.0000
# Epoch 2453/2500
# 2/2 [==============================] - 0s 158ms/step - loss: 0.0051 - accuracy: 0.9630 - val_loss: 0.0441 - val_accuracy: 1.0000
# Epoch 2454/2500
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0058 - accuracy: 0.9630 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 2455/2500
# 2/2 [==============================] - 0s 152ms/step - loss: 0.0045 - accuracy: 0.9630 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 2456/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0061 - accuracy: 0.9630 - val_loss: 0.0445 - val_accuracy: 1.0000
# Epoch 2457/2500
# 2/2 [==============================] - 0s 173ms/step - loss: 0.0042 - accuracy: 0.9444 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 2458/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0041 - accuracy: 0.9444 - val_loss: 0.0451 - val_accuracy: 1.0000
# Epoch 2459/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0043 - accuracy: 0.9444 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 2460/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0046 - accuracy: 0.9259 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 2461/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0035 - accuracy: 0.9444 - val_loss: 0.0439 - val_accuracy: 1.0000
# Epoch 2462/2500
# 2/2 [==============================] - 0s 168ms/step - loss: 0.0034 - accuracy: 0.9444 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 2463/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0047 - accuracy: 0.9630 - val_loss: 0.0454 - val_accuracy: 1.0000
# Epoch 2464/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0056 - accuracy: 0.9444 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 2465/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0059 - accuracy: 0.9444 - val_loss: 0.0462 - val_accuracy: 1.0000
# Epoch 2466/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0040 - accuracy: 0.9444 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 2467/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0497 - val_accuracy: 1.0000
# Epoch 2468/2500
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0037 - accuracy: 0.9259 - val_loss: 0.0507 - val_accuracy: 1.0000
# Epoch 2469/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0052 - accuracy: 0.9444 - val_loss: 0.0568 - val_accuracy: 1.0000
# Epoch 2470/2500
# 2/2 [==============================] - 0s 160ms/step - loss: 0.0062 - accuracy: 0.9444 - val_loss: 0.0438 - val_accuracy: 1.0000
# Epoch 2471/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0051 - accuracy: 0.9444 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 2472/2500
# 2/2 [==============================] - 0s 166ms/step - loss: 0.0042 - accuracy: 0.9444 - val_loss: 0.0483 - val_accuracy: 1.0000
# Epoch 2473/2500
# 2/2 [==============================] - 0s 171ms/step - loss: 0.0048 - accuracy: 0.9444 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 2474/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0523 - val_accuracy: 1.0000
# Epoch 2475/2500
# 2/2 [==============================] - 0s 172ms/step - loss: 0.0059 - accuracy: 0.9444 - val_loss: 0.0514 - val_accuracy: 1.0000
# Epoch 2476/2500
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0034 - accuracy: 0.9630 - val_loss: 0.0463 - val_accuracy: 0.9730
# Epoch 2477/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0057 - accuracy: 0.9444 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 2478/2500
# 2/2 [==============================] - 0s 159ms/step - loss: 0.0042 - accuracy: 0.9259 - val_loss: 0.0510 - val_accuracy: 1.0000
# Epoch 2479/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0054 - accuracy: 0.9630 - val_loss: 0.0457 - val_accuracy: 1.0000
# Epoch 2480/2500
# 2/2 [==============================] - 0s 165ms/step - loss: 0.0035 - accuracy: 0.9444 - val_loss: 0.0491 - val_accuracy: 1.0000
# Epoch 2481/2500
# 2/2 [==============================] - 0s 167ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0520 - val_accuracy: 1.0000
# Epoch 2482/2500
# 2/2 [==============================] - 0s 162ms/step - loss: 0.0037 - accuracy: 0.9630 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 2483/2500
# 2/2 [==============================] - 0s 154ms/step - loss: 0.0030 - accuracy: 0.9630 - val_loss: 0.0429 - val_accuracy: 1.0000
# Epoch 2484/2500
# 2/2 [==============================] - 0s 169ms/step - loss: 0.0034 - accuracy: 0.9444 - val_loss: 0.0496 - val_accuracy: 1.0000
# Epoch 2485/2500
# 2/2 [==============================] - 0s 161ms/step - loss: 0.0038 - accuracy: 0.9444 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 2486/2500
# 2/2 [==============================] - 0s 175ms/step - loss: 0.0029 - accuracy: 0.9259 - val_loss: 0.0511 - val_accuracy: 1.0000
# Epoch 2487/2500
# 2/2 [==============================] - 0s 157ms/step - loss: 0.0037 - accuracy: 0.9444 - val_loss: 0.0468 - val_accuracy: 1.0000
# Epoch 2488/2500
# 2/2 [==============================] - 0s 194ms/step - loss: 0.0027 - accuracy: 0.9444 - val_loss: 0.0492 - val_accuracy: 1.0000
# Epoch 2489/2500
# 2/2 [==============================] - 0s 184ms/step - loss: 0.0025 - accuracy: 0.9444 - val_loss: 0.0450 - val_accuracy: 1.0000
# Epoch 2490/2500
# 2/2 [==============================] - 0s 201ms/step - loss: 0.0032 - accuracy: 0.9630 - val_loss: 0.0537 - val_accuracy: 1.0000
# Epoch 2491/2500
# 2/2 [==============================] - 0s 200ms/step - loss: 0.0030 - accuracy: 0.9259 - val_loss: 0.0501 - val_accuracy: 1.0000
# Epoch 2492/2500
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0032 - accuracy: 0.9444 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 2493/2500
# 2/2 [==============================] - 0s 202ms/step - loss: 0.0038 - accuracy: 0.9259 - val_loss: 0.0477 - val_accuracy: 1.0000
# Epoch 2494/2500
# 2/2 [==============================] - 0s 203ms/step - loss: 0.0034 - accuracy: 0.9630 - val_loss: 0.0544 - val_accuracy: 1.0000
# Epoch 2495/2500
# 2/2 [==============================] - 0s 278ms/step - loss: 0.0037 - accuracy: 0.9444 - val_loss: 0.0513 - val_accuracy: 1.0000
# Epoch 2496/2500
# 2/2 [==============================] - 0s 210ms/step - loss: 0.0036 - accuracy: 0.9630 - val_loss: 0.0458 - val_accuracy: 1.0000
# Epoch 2497/2500
# 2/2 [==============================] - 0s 234ms/step - loss: 0.0038 - accuracy: 0.9630 - val_loss: 0.0543 - val_accuracy: 1.0000
# Epoch 2498/2500
# 2/2 [==============================] - 0s 209ms/step - loss: 0.0056 - accuracy: 0.9259 - val_loss: 0.0463 - val_accuracy: 1.0000
# Epoch 2499/2500
# 2/2 [==============================] - 0s 164ms/step - loss: 0.0036 - accuracy: 0.9444 - val_loss: 0.0530 - val_accuracy: 1.0000
# Epoch 2500/2500
# 2/2 [==============================] - 0s 163ms/step - loss: 0.0068 - accuracy: 0.9444 - val_loss: 0.0493 - val_accuracy: 1.0000

# %%
# create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))

ax1 = axes[0,0]
ax2 = axes[0,1]
ax3 = axes[1,0]

# plot the training and validation loss on the first subplot
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')
ax1.legend()

# plot the training and validation accuracy on the second subplot
ax2.plot(history.history['accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.legend()

# plot a histogram of the errors on a third subplot
errors = [1-acc for acc in history.history['accuracy']]
val_errors = [1-acc for acc in history.history['val_accuracy']]
ax3.hist(errors, bins=20, alpha=0.5, label='Training Errors')
ax3.hist(val_errors, bins=20, alpha=0.5, label='Validation Errors')
ax3.set_xlabel('Error')
ax3.set_ylabel('Count')
ax3.set_title('Histogram of Errors')
ax3.legend()

# remove the unused subplot
fig.delaxes(axes[1, 1])

# adjust the layout and display the figure
fig.tight_layout()
plt.show()

# %%
fig_ANN, (ax1_ANN) = plt.subplots(1,1)

ax1_ANN.plot(history.history['loss'])
ax1_ANN.plot(history.history['val_loss'])
ax1_ANN.set_title('Training and testing loss')
ax1_ANN.set_ylabel('loss')
ax1_ANN.set_xlabel('epoch')
ax1_ANN.legend(['training', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
ax1_ANN.set_xlim([0, 5000])
ax1_ANN.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
Y_data_ANNpred_scaled = history.model.predict(X_data_scaled)
Y_data_ANNpred = scaler_y.inverse_transform(Y_data_ANNpred_scaled)
Y_data_ANNpred_scaled = Y_data_ANNpred_scaled.reshape(n_cases,2)
Y_data_ANNpred = Y_data_ANNpred.reshape(n_cases,2)

print(Y_data_ANNpred_scaled.shape)
# Out:
# 3/3 [==============================] - 2s 59ms/step
# (91, 2)

# %%
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)
ax1_ANN.plot(cases, Y_data_scaled[:,0], 'o', markersize=10, color='black', label="testing points") # show training data
ax1_ANN.plot(cases, Y_data_ANNpred_scaled[:,0], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax1_ANN.set_ylabel('$K$')
ax1_ANN.set_xlabel('$cases$')


ax2_ANN.plot(cases, Y_data_scaled[:,1], 'o', markersize=10, color='black', label="testing points") # show training data
ax2_ANN.plot(cases, Y_data_ANNpred_scaled[:,1], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax2_ANN.set_ylabel('$n$')
ax2_ANN.set_xlabel('$cases$')
# ax2_ANN.set_xlim([-1, 1])
ax2_ANN.set_ylim([-1, 1])

# ax2_ANN.plot(Y_data[:,1,:], Y_data[:,0,:], 'o', markersize=10, color='gray', label="training points") # show training data
# ax2_ANN.plot(Y_data_ANNpred[:,1], Y_data_ANNpred[:,0], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
# ax2_ANN.set_ylabel('$K$')
# ax2_ANN.set_xlabel('$n$')
# # ax2_ANN.legend(loc='best')
# ax2_ANN.set_xlim([0, 0.4])
# ax2_ANN.set_ylim([200, 1800])
#ax2_ANN.grid(True, color='gray', linestyle='-')
# Create figure with specified size
fig_ANN.set_size_inches(22, 8)
