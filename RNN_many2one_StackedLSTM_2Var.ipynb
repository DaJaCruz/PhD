# %% [markdown]
# <a href="https://colab.research.google.com/github/DaJaCruz/PhD/blob/main/RNN_many2one_StackedLSTM_2Var.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages

import tensorflow as tf
import pandas as pd # Pandas dataframe (very common in ML)
import numpy as np # import numpy to handle a lot of things!
from tensorflow.keras.models import Sequential
import random
from keras.layers import Bidirectional
from tensorflow.keras.layers import Dense, Dropout, LSTM#, CuDNNLSTM
import matplotlib.pyplot as plt # import plotting tools to create figures
from IPython.display import display, Math # to print with Latex math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from matplotlib import cm # to change colors of surface plots

# Uncomment line below if you want to enable live rotation of the surface plots.
#%matplotlib notebook

# %%
! sudo apt-get install texlive-latex-recommended 
! sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended  
! wget http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip 
! unzip type1cm.zip -d /tmp/type1cm 
! cd /tmp/type1cm/type1cm/ && sudo latex type1cm.ins
! sudo mkdir /usr/share/texmf/tex/latex/type1cm 
! sudo cp /tmp/type1cm/type1cm/type1cm.sty /usr/share/texmf/tex/latex/type1cm 
! sudo texhash 
# !apt install cm-super
# Out:
# Reading package lists... Done
# ^C

# %%
# Basic plotting tools needed in Python.

#%config InlineBackend.figure_format = "retina" # render higher resolution images in the notebook
#plt.style.use("seaborn") # style for plotting that comes from seaborn
FS = 26  # Font Size
plt.rcParams['axes.facecolor'] = (0.97, 0.97, 0.97)
plt.rcParams['figure.facecolor'] = (1, 1, 1)
plt.rcParams["font.family"] = "sans"
plt.rcParams["font.serif"] = "Times New Roman"
plt.rcParams['font.size'] = FS
params = {"ytick.color": (0, 0, 0),
          "xtick.color": (0, 0, 0),
          "grid.color": (.9, .9, .9),
          "text.color": (0, 0, 0),
          "axes.labelcolor": (0, 0, 0),
          "axes.edgecolor": (.15, .15, .15)#,
          #"text.usetex": True
          }
plt.rcParams.update(params)
linewidth=3.0

# %%
# import raw data
url = 'https://raw.githubusercontent.com/DaJaCruz/PhD/main/data91_all.csv'
df = pd.read_csv(url, delimiter=';')

# %%
# Split raw data in Input (X) and Output (Y) data
X_data_raw = df.loc[:,['Input_4','Input_5']].values
Y_data_raw = df.loc[:,['Output_1','Output_3']].values

# %%
_, idx = np.unique(Y_data_raw, axis=0, return_index=True)
Y_data_unique_sorted = Y_data_raw[np.sort(idx)]
Y_dat_unique = Y_data_unique_sorted[:, 0].reshape(-1, 1)
print(Y_dat_unique, Y_data_unique_sorted)
# Out:
# [[1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]
#  [1000.]
#  [1100.]
#  [1200.]
#  [1300.]
#  [1400.]
#  [1500.]
#  [1600.]
#  [ 400.]
#  [ 500.]
#  [ 600.]
#  [ 700.]
#  [ 800.]
#  [ 900.]] [[1.0e+03 5.0e-02]
#  [1.1e+03 5.0e-02]
#  [1.2e+03 5.0e-02]
#  [1.3e+03 5.0e-02]
#  [1.4e+03 5.0e-02]
#  [1.5e+03 5.0e-02]
#  [1.6e+03 5.0e-02]
#  [4.0e+02 5.0e-02]
#  [5.0e+02 5.0e-02]
#  [6.0e+02 5.0e-02]
#  [7.0e+02 5.0e-02]
#  [8.0e+02 5.0e-02]
#  [9.0e+02 5.0e-02]
#  [1.0e+03 1.0e-01]
#  [1.1e+03 1.0e-01]
#  [1.2e+03 1.0e-01]
#  [1.3e+03 1.0e-01]
#  [1.4e+03 1.0e-01]
#  [1.5e+03 1.0e-01]
#  [1.6e+03 1.0e-01]
#  [4.0e+02 1.0e-01]
#  [5.0e+02 1.0e-01]
#  [6.0e+02 1.0e-01]
#  [7.0e+02 1.0e-01]
#  [8.0e+02 1.0e-01]
#  [9.0e+02 1.0e-01]
#  [1.0e+03 1.5e-01]
#  [1.1e+03 1.5e-01]
#  [1.2e+03 1.5e-01]
#  [1.3e+03 1.5e-01]
#  [1.4e+03 1.5e-01]
#  [1.5e+03 1.5e-01]
#  [1.6e+03 1.5e-01]
#  [4.0e+02 1.5e-01]
#  [5.0e+02 1.5e-01]
#  [6.0e+02 1.5e-01]
#  [7.0e+02 1.5e-01]
#  [8.0e+02 1.5e-01]
#  [9.0e+02 1.5e-01]
#  [1.0e+03 2.0e-01]
#  [1.1e+03 2.0e-01]
#  [1.2e+03 2.0e-01]
#  [1.3e+03 2.0e-01]
#  [1.4e+03 2.0e-01]
#  [1.5e+03 2.0e-01]
#  [1.6e+03 2.0e-01]
#  [4.0e+02 2.0e-01]
#  [5.0e+02 2.0e-01]
#  [6.0e+02 2.0e-01]
#  [7.0e+02 2.0e-01]
#  [8.0e+02 2.0e-01]
#  [9.0e+02 2.0e-01]
#  [1.0e+03 2.5e-01]
#  [1.1e+03 2.5e-01]
#  [1.2e+03 2.5e-01]
#  [1.3e+03 2.5e-01]
#  [1.4e+03 2.5e-01]
#  [1.5e+03 2.5e-01]
#  [1.6e+03 2.5e-01]
#  [4.0e+02 2.5e-01]
#  [5.0e+02 2.5e-01]
#  [6.0e+02 2.5e-01]
#  [7.0e+02 2.5e-01]
#  [8.0e+02 2.5e-01]
#  [9.0e+02 2.5e-01]
#  [1.0e+03 3.0e-01]
#  [1.1e+03 3.0e-01]
#  [1.2e+03 3.0e-01]
#  [1.3e+03 3.0e-01]
#  [1.4e+03 3.0e-01]
#  [1.5e+03 3.0e-01]
#  [1.6e+03 3.0e-01]
#  [4.0e+02 3.0e-01]
#  [5.0e+02 3.0e-01]
#  [6.0e+02 3.0e-01]
#  [7.0e+02 3.0e-01]
#  [8.0e+02 3.0e-01]
#  [9.0e+02 3.0e-01]
#  [1.0e+03 3.5e-01]
#  [1.1e+03 3.5e-01]
#  [1.2e+03 3.5e-01]
#  [1.3e+03 3.5e-01]
#  [1.4e+03 3.5e-01]
#  [1.5e+03 3.5e-01]
#  [1.6e+03 3.5e-01]
#  [4.0e+02 3.5e-01]
#  [5.0e+02 3.5e-01]
#  [6.0e+02 3.5e-01]
#  [7.0e+02 3.5e-01]
#  [8.0e+02 3.5e-01]
#  [9.0e+02 3.5e-01]]

# %%
# Reshape data 
X_data_shaped = X_data_raw.reshape((91, 500, 2))
Y_data_shaped = Y_data_unique_sorted

# %%
#Select the number of cases used 
n_cases = 91
time_step_1 = 50
time_step_2 = 400
n_timesteps = time_step_2-time_step_1
total_n_points= n_cases*n_timesteps
X_data = X_data_shaped[:n_cases, time_step_1:time_step_2, :]
Y_data = Y_data_shaped[:n_cases, :]

# %%
#Reshape X_data and Y_data to Normalization operation
X_data_reshaped_norm=X_data.reshape(total_n_points, 2)
Y_data_reshaped_norm=Y_data

# %%
#
#Scale Inputs with a [-1,1] scaler
scaler_x = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_x = StandardScaler()
#
scaler_x.fit(X_data_reshaped_norm)# fit the scaler to the input data
#
X_data_scaled_shaped=scaler_x.transform(X_data_reshaped_norm) # scale the input data (the whole dataset)
#
#Scale Inputs with a [-1,1] scaler
scaler_y = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_y = StandardScaler()
#
scaler_y.fit(Y_data_reshaped_norm) # fit the scaler to the output data
Y_data_scaled_shaped=scaler_y.transform(Y_data_reshaped_norm) # scale the output data (the whole dataset)

# %%
# Reshape data 
X_data_scaled = X_data_scaled_shaped.reshape((n_cases, n_timesteps, 2))
Y_data_scaled = Y_data_scaled_shaped

# %%
print('X_data =', X_data.shape)
print('Y_data =', Y_data)
print('X_data_scaled =', X_data_scaled.shape)
print('Y_data_Scaled =', Y_data_scaled)

# %%
#Plots with normalized and Non-normalized inputs
fig_ANN, ((ax1_ANN, ax2_ANN), (ax3_ANN, ax4_ANN)) = plt.subplots(nrows=2, ncols=2, figsize=(30, 20))

#Case Studies to represent
Case_1 = 3
Case_2 = 4
Case_3 = 5

#Force Displacement Curves
ax1_ANN.plot(X_data[Case_1,:,0], X_data[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_2,:,0], X_data[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_3,:,0], X_data[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax1_ANN.set_xlabel('Time, $t$ [s]')
ax1_ANN.set_title('Non-normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([0, 10])
# ax1_ANN.set_xlim([0, 20])

# K-n Points
ax2_ANN.plot(Y_data[Case_1,1], Y_data[Case_1,0], 'o', markersize=10, color='blue') # show normalized training data
ax2_ANN.plot(Y_data[Case_2,1], Y_data[Case_2,0], 'o', markersize=10, color='gray') # show normalized training data
ax2_ANN.plot(Y_data[Case_3,1], Y_data[Case_3,0], 'o', markersize=10, color='red') # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Non-normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([200, 1800])
# ax2_ANN.set_xlim([0, 0.4])

ax3_ANN.plot(X_data_scaled[Case_1,:,0], X_data_scaled[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_2,:,0], X_data_scaled[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_3,:,0], X_data_scaled[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax3_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax3_ANN.set_xlabel('Time, $t$ [s]')
ax3_ANN.set_title('Normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax3_ANN.set_ylim([-1, 1])
# ax3_ANN.set_xlim([-1, 1])

# K-n Points
ax4_ANN.plot(Y_data[Case_1,1], Y_data_scaled[Case_1,0], 'o', markersize=10, color='blue') # show normalized training data
ax4_ANN.plot(Y_data[Case_2,1], Y_data_scaled[Case_2,0], 'o', markersize=10, color='gray') # show normalized training data
ax4_ANN.plot(Y_data[Case_3,1], Y_data_scaled[Case_3,0], 'o', markersize=10, color='red') # show normalized training data
ax4_ANN.set_ylabel('$K$')
ax4_ANN.set_xlabel('$n$')
ax4_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax4_ANN.set_ylim([-1.25, 1.25])
# ax4_ANN.set_xlim([-1.25, 1.25])


# Create figure with specified size
# fig_ANN.set_size_inches(22, 10)
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
print(Y_data_scaled[:,0,:])

# %%
# Divide datasets into train and test 

seed = random.randint(1, 50000) # set a random seed to replicate results
# seed = 15448
np.random.seed(seed)

testvalset_ratio = 0.4 # ratio of test set points from the dataset

X_train_scaled, X_test_scaled, Y_train_scaled, Y_test_scaled = train_test_split(X_data_scaled, Y_data_scaled,
                                                    test_size=testvalset_ratio,random_state=seed
                                                    )

print(seed)
# Out:
# 17276

# %%
#Plots with normalized and Non-normalized outputs
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)

ax1_ANN.plot(X_test_scaled[:,:,0], X_test_scaled[:,:,1], 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax1_ANN.plot(X_train_scaled[:,:,0], X_train_scaled[:,:,1], 'o', markersize=10, color='gray', label="training points") # show normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$')
ax1_ANN.set_xlabel('Punch Displacement, $y_p$')
ax1_ANN.set_title('Normalized input data')
# ax1_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([-1.25, 1.25])
# ax1_ANN.set_xlim([-1.25, 1.25])
# Create figure with specified size
fig_ANN.set_size_inches(22, 10)

# K-n Points
ax2_ANN.plot(Y_test_scaled[:,0], Y_test_scaled[:,1], 'o', markersize=10, color='black') # show normalized training data
ax2_ANN.plot(Y_train_scaled[:,0], Y_train_scaled[:,1], 'o', markersize=10, color='gray') # show normalized training data
# ax2_ANN.plot(cases, Y_test_scaled, 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([-1.25, 1.25])
# ax2_ANN.set_xlim([-1.25, 1.25])
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
# Build the Bidirectional LSTM model
model = Sequential()
model.add(Bidirectional(LSTM(n_timesteps, return_sequences=True, input_shape=(n_timesteps, 2), activation='tanh')))
# model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(50)))
# model.add(Dropout(0.2))
model.add(Dense(10, activation = "tanh"))
model.add(Dense(2, activation = "linear"))
model.compile()

# %%
# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='mean_squared_error',
              optimizer=opt, metrics=['accuracy'])

# %%
# Train the model
history = model.fit(X_train_scaled, Y_train_scaled, validation_data=(X_test_scaled, Y_test_scaled), epochs=100)
# Out:
# Epoch 1/100
# 2/2 [==============================] - 0s 234ms/step - loss: 0.2040 - accuracy: 0.9630 - val_loss: 0.2373 - val_accuracy: 0.9730
# Epoch 2/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2119 - accuracy: 0.9074 - val_loss: 0.1838 - val_accuracy: 0.9459
# Epoch 3/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2144 - accuracy: 0.8519 - val_loss: 0.1749 - val_accuracy: 0.9730
# Epoch 4/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.2042 - accuracy: 0.9259 - val_loss: 0.2256 - val_accuracy: 0.9189
# Epoch 5/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2188 - accuracy: 0.9444 - val_loss: 0.1557 - val_accuracy: 0.9730
# Epoch 6/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.1812 - accuracy: 0.9074 - val_loss: 0.2279 - val_accuracy: 0.9730
# Epoch 7/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2002 - accuracy: 0.9074 - val_loss: 0.2133 - val_accuracy: 0.9730
# Epoch 8/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.1945 - accuracy: 0.9074 - val_loss: 0.1614 - val_accuracy: 0.9730
# Epoch 9/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.1923 - accuracy: 0.9444 - val_loss: 0.2676 - val_accuracy: 0.8919
# Epoch 10/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2901 - accuracy: 0.9259 - val_loss: 0.1789 - val_accuracy: 0.9459
# Epoch 11/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2920 - accuracy: 0.8519 - val_loss: 0.1734 - val_accuracy: 0.9459
# Epoch 12/100
# 2/2 [==============================] - 0s 178ms/step - loss: 0.2094 - accuracy: 0.8333 - val_loss: 0.2523 - val_accuracy: 0.9730
# Epoch 13/100
# 2/2 [==============================] - 0s 257ms/step - loss: 0.2575 - accuracy: 0.9259 - val_loss: 0.2454 - val_accuracy: 0.9730
# Epoch 14/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.2507 - accuracy: 0.8519 - val_loss: 0.1934 - val_accuracy: 0.9730
# Epoch 15/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.2328 - accuracy: 0.8704 - val_loss: 0.1980 - val_accuracy: 0.8649
# Epoch 16/100
# 2/2 [==============================] - 0s 256ms/step - loss: 0.2538 - accuracy: 0.7963 - val_loss: 0.1995 - val_accuracy: 0.8649
# Epoch 17/100
# 2/2 [==============================] - 0s 209ms/step - loss: 0.2550 - accuracy: 0.7963 - val_loss: 0.2443 - val_accuracy: 0.9730
# Epoch 18/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.2458 - accuracy: 0.9259 - val_loss: 0.2552 - val_accuracy: 0.8108
# Epoch 19/100
# 2/2 [==============================] - 0s 184ms/step - loss: 0.2776 - accuracy: 0.7407 - val_loss: 0.2562 - val_accuracy: 0.9459
# Epoch 20/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2617 - accuracy: 0.9259 - val_loss: 0.2119 - val_accuracy: 0.9459
# Epoch 21/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2450 - accuracy: 0.8333 - val_loss: 0.1978 - val_accuracy: 0.9459
# Epoch 22/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2358 - accuracy: 0.9630 - val_loss: 0.1844 - val_accuracy: 0.9459
# Epoch 23/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.2330 - accuracy: 0.9444 - val_loss: 0.1900 - val_accuracy: 0.9730
# Epoch 24/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.2356 - accuracy: 0.9444 - val_loss: 0.1977 - val_accuracy: 0.9459
# Epoch 25/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2346 - accuracy: 0.9259 - val_loss: 0.2048 - val_accuracy: 0.9730
# Epoch 26/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2298 - accuracy: 0.9259 - val_loss: 0.2119 - val_accuracy: 0.9730
# Epoch 27/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2302 - accuracy: 0.9630 - val_loss: 0.2225 - val_accuracy: 0.9459
# Epoch 28/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2330 - accuracy: 0.9444 - val_loss: 0.2106 - val_accuracy: 0.9730
# Epoch 29/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2254 - accuracy: 0.9444 - val_loss: 0.2037 - val_accuracy: 0.9730
# Epoch 30/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.2246 - accuracy: 0.9444 - val_loss: 0.1984 - val_accuracy: 0.9730
# Epoch 31/100
# 2/2 [==============================] - 0s 155ms/step - loss: 0.2223 - accuracy: 0.9630 - val_loss: 0.1917 - val_accuracy: 0.9459
# Epoch 32/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2235 - accuracy: 0.9444 - val_loss: 0.1883 - val_accuracy: 0.9730
# Epoch 33/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2248 - accuracy: 0.9444 - val_loss: 0.1892 - val_accuracy: 0.9730
# Epoch 34/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2225 - accuracy: 0.9444 - val_loss: 0.1941 - val_accuracy: 0.9730
# Epoch 35/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2215 - accuracy: 0.9444 - val_loss: 0.2016 - val_accuracy: 0.9730
# Epoch 36/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2230 - accuracy: 0.9444 - val_loss: 0.2074 - val_accuracy: 0.9730
# Epoch 37/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2248 - accuracy: 0.9444 - val_loss: 0.2065 - val_accuracy: 0.9459
# Epoch 38/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2226 - accuracy: 0.9444 - val_loss: 0.1988 - val_accuracy: 0.9459
# Epoch 39/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2249 - accuracy: 0.9630 - val_loss: 0.1918 - val_accuracy: 0.9730
# Epoch 40/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2221 - accuracy: 0.9444 - val_loss: 0.1906 - val_accuracy: 0.9730
# Epoch 41/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2217 - accuracy: 0.9259 - val_loss: 0.1953 - val_accuracy: 0.9730
# Epoch 42/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2214 - accuracy: 0.9444 - val_loss: 0.1994 - val_accuracy: 0.9730
# Epoch 43/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2221 - accuracy: 0.9444 - val_loss: 0.2049 - val_accuracy: 0.9730
# Epoch 44/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2226 - accuracy: 0.9259 - val_loss: 0.2054 - val_accuracy: 0.9730
# Epoch 45/100
# 2/2 [==============================] - 0s 156ms/step - loss: 0.2209 - accuracy: 0.9444 - val_loss: 0.1987 - val_accuracy: 0.9459
# Epoch 46/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2210 - accuracy: 0.9444 - val_loss: 0.1948 - val_accuracy: 0.9459
# Epoch 47/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2232 - accuracy: 0.9630 - val_loss: 0.1923 - val_accuracy: 0.9459
# Epoch 48/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2214 - accuracy: 0.9630 - val_loss: 0.1956 - val_accuracy: 0.9730
# Epoch 49/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2189 - accuracy: 0.9444 - val_loss: 0.2019 - val_accuracy: 0.9730
# Epoch 50/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2182 - accuracy: 0.9259 - val_loss: 0.2092 - val_accuracy: 0.9730
# Epoch 51/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2213 - accuracy: 0.9259 - val_loss: 0.2111 - val_accuracy: 0.9730
# Epoch 52/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2182 - accuracy: 0.9444 - val_loss: 0.2155 - val_accuracy: 0.9459
# Epoch 53/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2194 - accuracy: 0.9630 - val_loss: 0.2158 - val_accuracy: 0.9730
# Epoch 54/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.2189 - accuracy: 0.9444 - val_loss: 0.2162 - val_accuracy: 0.9730
# Epoch 55/100
# 2/2 [==============================] - 0s 157ms/step - loss: 0.2184 - accuracy: 0.9630 - val_loss: 0.2109 - val_accuracy: 0.9459
# Epoch 56/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.2201 - accuracy: 0.9630 - val_loss: 0.2052 - val_accuracy: 0.9459
# Epoch 57/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.2179 - accuracy: 0.9630 - val_loss: 0.2032 - val_accuracy: 0.9730
# Epoch 58/100
# 2/2 [==============================] - 0s 158ms/step - loss: 0.2167 - accuracy: 0.9444 - val_loss: 0.1993 - val_accuracy: 0.9730
# Epoch 59/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2174 - accuracy: 0.9074 - val_loss: 0.2019 - val_accuracy: 0.9730
# Epoch 60/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2164 - accuracy: 0.9259 - val_loss: 0.2042 - val_accuracy: 0.9730
# Epoch 61/100
# 2/2 [==============================] - 0s 187ms/step - loss: 0.2171 - accuracy: 0.9259 - val_loss: 0.2069 - val_accuracy: 0.9730
# Epoch 62/100
# 2/2 [==============================] - 0s 191ms/step - loss: 0.2166 - accuracy: 0.9444 - val_loss: 0.2064 - val_accuracy: 0.9730
# Epoch 63/100
# 2/2 [==============================] - 0s 180ms/step - loss: 0.2158 - accuracy: 0.9444 - val_loss: 0.2082 - val_accuracy: 0.9730
# Epoch 64/100
# 2/2 [==============================] - 0s 185ms/step - loss: 0.2157 - accuracy: 0.9259 - val_loss: 0.2035 - val_accuracy: 0.9730
# Epoch 65/100
# 2/2 [==============================] - 0s 176ms/step - loss: 0.2156 - accuracy: 0.9259 - val_loss: 0.2009 - val_accuracy: 0.9459
# Epoch 66/100
# 2/2 [==============================] - 0s 173ms/step - loss: 0.2186 - accuracy: 0.9444 - val_loss: 0.2039 - val_accuracy: 0.9730
# Epoch 67/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2171 - accuracy: 0.9259 - val_loss: 0.2138 - val_accuracy: 0.9730
# Epoch 68/100
# 2/2 [==============================] - 0s 186ms/step - loss: 0.2151 - accuracy: 0.9444 - val_loss: 0.2156 - val_accuracy: 0.9730
# Epoch 69/100
# 2/2 [==============================] - 0s 180ms/step - loss: 0.2145 - accuracy: 0.9259 - val_loss: 0.2155 - val_accuracy: 0.9730
# Epoch 70/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2193 - accuracy: 0.9259 - val_loss: 0.2059 - val_accuracy: 0.9730
# Epoch 71/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.2139 - accuracy: 0.9444 - val_loss: 0.2096 - val_accuracy: 0.9459
# Epoch 72/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.2222 - accuracy: 0.9630 - val_loss: 0.2207 - val_accuracy: 0.9730
# Epoch 73/100
# 2/2 [==============================] - 0s 159ms/step - loss: 0.2162 - accuracy: 0.9444 - val_loss: 0.2101 - val_accuracy: 0.9730
# Epoch 74/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2160 - accuracy: 0.9444 - val_loss: 0.2017 - val_accuracy: 0.9730
# Epoch 75/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2146 - accuracy: 0.9630 - val_loss: 0.2054 - val_accuracy: 0.9730
# Epoch 76/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2121 - accuracy: 0.9444 - val_loss: 0.2178 - val_accuracy: 0.9730
# Epoch 77/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2146 - accuracy: 0.9259 - val_loss: 0.2137 - val_accuracy: 0.9730
# Epoch 78/100
# 2/2 [==============================] - 0s 172ms/step - loss: 0.2133 - accuracy: 0.9444 - val_loss: 0.2065 - val_accuracy: 0.9730
# Epoch 79/100
# 2/2 [==============================] - 0s 170ms/step - loss: 0.2157 - accuracy: 0.9444 - val_loss: 0.2016 - val_accuracy: 0.9730
# Epoch 80/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.2120 - accuracy: 0.9444 - val_loss: 0.2020 - val_accuracy: 0.9730
# Epoch 81/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2104 - accuracy: 0.9259 - val_loss: 0.2092 - val_accuracy: 0.9730
# Epoch 82/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2110 - accuracy: 0.9259 - val_loss: 0.2117 - val_accuracy: 0.9730
# Epoch 83/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2147 - accuracy: 0.9444 - val_loss: 0.2013 - val_accuracy: 0.9459
# Epoch 84/100
# 2/2 [==============================] - 0s 166ms/step - loss: 0.2071 - accuracy: 0.9444 - val_loss: 0.2116 - val_accuracy: 0.9730
# Epoch 85/100
# 2/2 [==============================] - 0s 162ms/step - loss: 0.2064 - accuracy: 0.9259 - val_loss: 0.1953 - val_accuracy: 0.9459
# Epoch 86/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2198 - accuracy: 0.9444 - val_loss: 0.2531 - val_accuracy: 0.8649
# Epoch 87/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2310 - accuracy: 0.8333 - val_loss: 0.2086 - val_accuracy: 0.9459
# Epoch 88/100
# 2/2 [==============================] - 0s 171ms/step - loss: 0.2266 - accuracy: 0.9259 - val_loss: 0.1868 - val_accuracy: 0.9459
# Epoch 89/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2200 - accuracy: 0.9259 - val_loss: 0.1907 - val_accuracy: 0.9459
# Epoch 90/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2251 - accuracy: 0.8333 - val_loss: 0.2024 - val_accuracy: 0.9730
# Epoch 91/100
# 2/2 [==============================] - 0s 165ms/step - loss: 0.2154 - accuracy: 0.9259 - val_loss: 0.1997 - val_accuracy: 0.8919
# Epoch 92/100
# 2/2 [==============================] - 0s 161ms/step - loss: 0.2185 - accuracy: 0.9259 - val_loss: 0.2066 - val_accuracy: 0.9459
# Epoch 93/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2228 - accuracy: 0.9259 - val_loss: 0.2308 - val_accuracy: 0.9459
# Epoch 94/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2223 - accuracy: 0.8519 - val_loss: 0.1983 - val_accuracy: 0.9730
# Epoch 95/100
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2100 - accuracy: 0.9259 - val_loss: 0.1948 - val_accuracy: 0.9459
# Epoch 96/100
# 2/2 [==============================] - 0s 169ms/step - loss: 0.2111 - accuracy: 0.9074 - val_loss: 0.2178 - val_accuracy: 0.9459
# Epoch 97/100
# 2/2 [==============================] - 0s 160ms/step - loss: 0.2126 - accuracy: 0.9630 - val_loss: 0.2135 - val_accuracy: 0.9730
# Epoch 98/100
# 2/2 [==============================] - 0s 163ms/step - loss: 0.2054 - accuracy: 0.9074 - val_loss: 0.1895 - val_accuracy: 0.9730
# Epoch 99/100
# 2/2 [==============================] - 0s 164ms/step - loss: 0.2214 - accuracy: 0.9444 - val_loss: 0.1969 - val_accuracy: 0.9459
# Epoch 100/100
# 2/2 [==============================] - 0s 168ms/step - loss: 0.2227 - accuracy: 0.9630 - val_loss: 0.2235 - val_accuracy: 0.9730

# %%
# Save the weights of the model at a specific epoch
model.save_weights('checkpoint_epoch_50')

# Load the saved weights at epoch 5
model.load_weights('checkpoint_epoch_50')


# Use the model for prediction on new data
# y_pred = model.predict(x_test)

# %%
# create a figure with two subplots
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 10))

ax1 = axes[0,0]
ax2 = axes[0,1]
ax3 = axes[1,0]

# plot the training and validation loss on the first subplot
ax1.plot(history.history['loss'], label='Training Loss')
ax1.plot(history.history['val_loss'], label='Validation Loss')
ax1.set_xlabel('Epochs')
ax1.set_ylabel('Loss')
ax1.set_title('Training and Validation Loss')
ax1.legend()

# plot the training and validation accuracy on the second subplot
ax2.plot(history.history['accuracy'], label='Training Accuracy')
ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
ax2.set_xlabel('Epochs')
ax2.set_ylabel('Accuracy')
ax2.set_title('Training and Validation Accuracy')
ax2.legend()

# plot a histogram of the errors on a third subplot
errors = [1-acc for acc in history.history['accuracy']]
val_errors = [1-acc for acc in history.history['val_accuracy']]
ax3.hist(errors, bins=20, alpha=0.5, label='Training Errors')
ax3.hist(val_errors, bins=20, alpha=0.5, label='Validation Errors')
ax3.set_xlabel('Error')
ax3.set_ylabel('Count')
ax3.set_title('Histogram of Errors')
ax3.legend()

# remove the unused subplot
fig.delaxes(axes[1, 1])

# adjust the layout and display the figure
fig.tight_layout()
plt.show()

# %%
Y_data_ANNpred_scaled = model.predict(X_data_scaled)
Y_data_ANNpred = scaler_y.inverse_transform(Y_data_ANNpred_scaled)
Y_data_ANNpred_scaled = Y_data_ANNpred_scaled.reshape(n_cases,2)
Y_data_ANNpred = Y_data_ANNpred.reshape(n_cases,2)

print(Y_data_ANNpred_scaled.shape)
# Out:
# 3/3 [==============================] - 0s 65ms/step
# (91, 2)

# %%
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)
ax1_ANN.plot(cases, Y_data_scaled[:,0], 'o', markersize=10, color='black', label="testing points") # show training data
ax1_ANN.plot(cases, Y_data_ANNpred_scaled[:,0], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax1_ANN.set_ylabel('$K$')
ax1_ANN.set_xlabel('$cases$')


ax2_ANN.plot(cases, Y_data_scaled[:,1], 'o', markersize=10, color='black', label="testing points") # show training data
ax2_ANN.plot(cases, Y_data_ANNpred_scaled[:,1], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax2_ANN.set_ylabel('$n$')
ax2_ANN.set_xlabel('$cases$')
# ax2_ANN.set_xlim([-1, 1])
ax2_ANN.set_ylim([-1, 1])

# ax2_ANN.plot(Y_data[:,1,:], Y_data[:,0,:], 'o', markersize=10, color='gray', label="training points") # show training data
# ax2_ANN.plot(Y_data_ANNpred[:,1], Y_data_ANNpred[:,0], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
# ax2_ANN.set_ylabel('$K$')
# ax2_ANN.set_xlabel('$n$')
# # ax2_ANN.legend(loc='best')
# ax2_ANN.set_xlim([0, 0.4])
# ax2_ANN.set_ylim([200, 1800])
#ax2_ANN.grid(True, color='gray', linestyle='-')
# Create figure with specified size
fig_ANN.set_size_inches(22, 8)

# %%
fig_ANN, (ax1_ANN) = plt.subplots(1,1)

ax1_ANN.plot(history.history['loss'])
ax1_ANN.plot(history.history['val_loss'])
ax1_ANN.set_title('Training and testing loss')
ax1_ANN.set_ylabel('loss')
ax1_ANN.set_xlabel('epoch')
ax1_ANN.legend(['training', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
ax1_ANN.set_xlim([0, 5000])
ax1_ANN.set_ylim([0, 1])
# Out:
# (0.0, 1.0)
