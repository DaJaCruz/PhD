# %% [markdown]
# <a href="https://colab.research.google.com/github/DaJaCruz/PhD/blob/main/RNN_many2one_BidirectionalLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import packages

import tensorflow as tf
import pandas as pd # Pandas dataframe (very common in ML)
import numpy as np # import numpy to handle a lot of things!
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM#, CuDNNLSTM
import matplotlib.pyplot as plt # import plotting tools to create figures
from IPython.display import display, Math # to print with Latex math
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from matplotlib import cm # to change colors of surface plots

# Uncomment line below if you want to enable live rotation of the surface plots.
#%matplotlib notebook

# %%
! sudo apt-get install texlive-latex-recommended 
! sudo apt-get install dvipng texlive-latex-extra texlive-fonts-recommended  
! wget http://mirrors.ctan.org/macros/latex/contrib/type1cm.zip 
! unzip type1cm.zip -d /tmp/type1cm 
! cd /tmp/type1cm/type1cm/ && sudo latex type1cm.ins
! sudo mkdir /usr/share/texmf/tex/latex/type1cm 
! sudo cp /tmp/type1cm/type1cm/type1cm.sty /usr/share/texmf/tex/latex/type1cm 
! sudo texhash 
# !apt install cm-super

# %%
# Basic plotting tools needed in Python.

#%config InlineBackend.figure_format = "retina" # render higher resolution images in the notebook
#plt.style.use("seaborn") # style for plotting that comes from seaborn
FS = 26  # Font Size
plt.rcParams['axes.facecolor'] = (0.97, 0.97, 0.97)
plt.rcParams['figure.facecolor'] = (1, 1, 1)
plt.rcParams["font.family"] = "sans"
plt.rcParams["font.serif"] = "Times New Roman"
plt.rcParams['font.size'] = FS
params = {"ytick.color": (0, 0, 0),
          "xtick.color": (0, 0, 0),
          "grid.color": (.9, .9, .9),
          "text.color": (0, 0, 0),
          "axes.labelcolor": (0, 0, 0),
          "axes.edgecolor": (.15, .15, .15)#,
          #"text.usetex": True
          }
plt.rcParams.update(params)
linewidth=3.0

# %%
# import raw data
url = 'https://raw.githubusercontent.com/DaJaCruz/PhD/main/data91_all.csv'
df = pd.read_csv(url, delimiter=';')

# %%
# Split raw data in Input (X) and Output (Y) data
X_data_raw = df.loc[:,['Input_4','Input_5']].values
Y_data_raw = df.loc[:,['Output_1','Output_3']].values

# %%
_, idx = np.unique(Y_data_raw, axis=0, return_index=True)
Y_data_unique_sorted = Y_data_raw[np.sort(idx)]
Y_dat_unique = Y_data_unique_sorted[:, 0].reshape(-1, 1)
print(X_data_raw.shape, Y_data_unique_sorted.shape)
# Out:
# (45500, 2) (91, 2)

# %%
# Reshape data 
X_data_shaped = X_data_raw.reshape((91, 500, 2))
Y_data_shaped = Y_dat_unique.reshape((91, 1, 1))

# %%
#Select the number of cases used 
n_cases = 20
total_n_points= n_cases*500
X_data = X_data_shaped[:n_cases, :, :]
Y_data = Y_data_shaped[:n_cases, :, :]

# %%
#Reshape X_data and Y_data to Normalization operation
X_data_reshaped_norm=X_data.reshape(total_n_points, 2)
Y_data_reshaped_norm=Y_data.reshape(n_cases, 1)

# %%
#
#Scale Inputs with a [-1,1] scaler
scaler_x = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_x = StandardScaler()
#
scaler_x.fit(X_data_reshaped_norm)# fit the scaler to the input data
#
X_data_scaled_shaped=scaler_x.transform(X_data_reshaped_norm) # scale the input data (the whole dataset)
#
#Scale Inputs with a [-1,1] scaler
scaler_y = MinMaxScaler(feature_range=(-1,1))
#
# Scaling inputs with a Standard Scaler:
#scaler_y = StandardScaler()
#
scaler_y.fit(Y_data_reshaped_norm) # fit the scaler to the output data
Y_data_scaled_shaped=scaler_y.transform(Y_data_reshaped_norm) # scale the output data (the whole dataset)

# %%
# Reshape data 
X_data_scaled = X_data_scaled_shaped.reshape((n_cases, 500, 2))
Y_data_scaled = Y_data_scaled_shaped.reshape((n_cases, 1, 1))

# %%
print('X_data =', X_data.shape)
print('Y_data =', Y_data.shape)
print('X_data_scaled =', X_data_scaled.shape)
print('Y_data_Scaled =', Y_data_scaled.shape)

# %%
#Plots with normalized and Non-normalized inputs
fig_ANN, ((ax1_ANN, ax2_ANN), (ax3_ANN, ax4_ANN)) = plt.subplots(nrows=2, ncols=2, figsize=(30, 20))

#Case Studies to represent
Case_1 = 3
Case_2 = 4
Case_3 = 5

#Force Displacement Curves
ax1_ANN.plot(X_data[Case_1,:,0], X_data[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_2,:,0], X_data[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax1_ANN.plot(X_data[Case_3,:,0], X_data[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax1_ANN.set_xlabel('Time, $t$ [s]')
ax1_ANN.set_title('Non-normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([0, 10])
# ax1_ANN.set_xlim([0, 20])

# K-n Points
ax2_ANN.plot(Case_1, Y_data[Case_1,0,:], 'o', markersize=10, color='blue') # show normalized training data
ax2_ANN.plot(Case_2, Y_data[Case_2,0,:], 'o', markersize=10, color='gray') # show normalized training data
ax2_ANN.plot(Case_3, Y_data[Case_3,0,:], 'o', markersize=10, color='red') # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Non-normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([200, 1800])
# ax2_ANN.set_xlim([0, 0.4])

ax3_ANN.plot(X_data_scaled[Case_1,:,0], X_data_scaled[Case_1,:,1], 'o', markersize=10, color='blue', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_2,:,0], X_data_scaled[Case_2,:,1], 'o', markersize=10, color='gray', label="training points") # show Non-normalized training data
ax3_ANN.plot(X_data_scaled[Case_3,:,0], X_data_scaled[Case_3,:,1], 'o', markersize=10, color='red', label="training points") # show Non-normalized training data
ax3_ANN.set_ylabel('Punch Force, $F_p$ [kN]')
ax3_ANN.set_xlabel('Time, $t$ [s]')
ax3_ANN.set_title('Normalized input data')
#ax1_ANN.legen#d(['training', 'testing', 'validation' ], loc='best')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax3_ANN.set_ylim([-1, 1])
# ax3_ANN.set_xlim([-1, 1])

# K-n Points
ax4_ANN.plot(Case_1, Y_data_scaled[Case_1,0,:], 'o', markersize=10, color='blue') # show normalized training data
ax4_ANN.plot(Case_3, Y_data_scaled[Case_2,0,:], 'o', markersize=10, color='gray') # show normalized training data
ax4_ANN.plot(Case_2, Y_data_scaled[Case_3,0,:], 'o', markersize=10, color='red') # show normalized training data
ax4_ANN.set_ylabel('$K$')
ax4_ANN.set_xlabel('$n$')
ax4_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax4_ANN.set_ylim([-1.25, 1.25])
# ax4_ANN.set_xlim([-1.25, 1.25])


# Create figure with specified size
# fig_ANN.set_size_inches(22, 10)
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
print(Y_data_scaled[:,0,:])

# %%
# Divide datasets into train and test 

seed = 1000 # set a random seed to replicate results
np.random.seed(seed)

testvalset_ratio = 0.2 # ratio of test set points from the dataset

X_train_scaled, X_test_scaled, Y_train_scaled, Y_test_scaled = train_test_split(X_data_scaled, Y_data_scaled[:,0,:],
                                                    test_size=testvalset_ratio,random_state=seed
                                                    )

print(Y_train_scaled.shape)
# Out:
# (16, 1)

# %%
#Plots with normalized and Non-normalized outputs
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)

ax1_ANN.plot(X_test_scaled[:,:,0], X_test_scaled[:,:,1], 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax1_ANN.plot(X_train_scaled[:,:,0], X_train_scaled[:,:,1], 'o', markersize=10, color='gray', label="training points") # show normalized training data
ax1_ANN.set_ylabel('Punch Force, $F_p$')
ax1_ANN.set_xlabel('Punch Displacement, $y_p$')
ax1_ANN.set_title('Normalized input data')
# ax1_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax1_ANN.set_ylim([-1.25, 1.25])
# ax1_ANN.set_xlim([-1.25, 1.25])
# Create figure with specified size
fig_ANN.set_size_inches(22, 10)

# K-n Points
ax2_ANN.plot(cases, Y_data[:,0,:], 'o', markersize=10, color='gray') # show normalized training data
# ax2_ANN.plot(cases, Y_test_scaled, 'o', markersize=10, color='black', label="testing points") # show normalized training data
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$n$')
ax2_ANN.set_title('Normalized output data')
# ax2_ANN.legend(['training', 'testing', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
# ax2_ANN.set_ylim([-1.25, 1.25])
# ax2_ANN.set_xlim([-1.25, 1.25])
# Out:
# Text(0.5, 1.0, 'Normalized output data')

# %%
# Build the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(500, 2), activation='tanh'))
model.add(Dense(100, activation = "tanh"))
model.add(Dense(1, activation = "linear"))

# %%
# Compile the model
opt = tf.keras.optimizers.Adam(learning_rate=0.01)
model.compile(loss='mean_squared_error',
              optimizer=opt)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50)                10600
#
#  dense (Dense)               (None, 100)               5100
#
#  dense_1 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 15,801
# Trainable params: 15,801
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train_scaled, Y_train_scaled, validation_data=(X_test_scaled, Y_test_scaled), epochs=500,  batch_size = 500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 9s 9s/step - loss: 0.3234 - val_loss: 0.0555
# Epoch 2/500
# 1/1 [==============================] - 0s 59ms/step - loss: 1.2402 - val_loss: 0.4832
# Epoch 3/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2914 - val_loss: 1.1554
# Epoch 4/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.4612 - val_loss: 1.0965
# Epoch 5/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.4271 - val_loss: 0.8247
# Epoch 6/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.3243 - val_loss: 0.5859
# Epoch 7/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3004 - val_loss: 0.4342
# Epoch 8/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.3275 - val_loss: 0.3777
# Epoch 9/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3405 - val_loss: 0.3885
# Epoch 10/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.3242 - val_loss: 0.4380
# Epoch 11/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.2995 - val_loss: 0.5031
# Epoch 12/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2824 - val_loss: 0.5606
# Epoch 13/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2757 - val_loss: 0.5815
# Epoch 14/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2720 - val_loss: 0.5313
# Epoch 15/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2582 - val_loss: 0.3736
# Epoch 16/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2218 - val_loss: 0.0926
# Epoch 17/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.1647 - val_loss: 0.2149
# Epoch 18/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.3449 - val_loss: 0.1863
# Epoch 19/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.1524 - val_loss: 0.5162
# Epoch 20/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.2913 - val_loss: 0.6114
# Epoch 21/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.3234 - val_loss: 0.5412
# Epoch 22/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.2743 - val_loss: 0.4192
# Epoch 23/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2240 - val_loss: 0.3042
# Epoch 24/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2043 - val_loss: 0.2126
# Epoch 25/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.2096 - val_loss: 0.1456
# Epoch 26/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.2255 - val_loss: 0.1013
# Epoch 27/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.2371 - val_loss: 0.0766
# Epoch 28/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.2309 - val_loss: 0.0672
# Epoch 29/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.1995 - val_loss: 0.0683
# Epoch 30/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.1472 - val_loss: 0.0724
# Epoch 31/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0949 - val_loss: 0.0606
# Epoch 32/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0768 - val_loss: 0.0293
# Epoch 33/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0674 - val_loss: 0.2798
# Epoch 34/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0894 - val_loss: 0.1710
# Epoch 35/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0453 - val_loss: 0.0392
# Epoch 36/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0300 - val_loss: 0.0239
# Epoch 37/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0342 - val_loss: 0.0219
# Epoch 38/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0352 - val_loss: 0.0198
# Epoch 39/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0453 - val_loss: 0.0191
# Epoch 40/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0497 - val_loss: 0.0196
# Epoch 41/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0402 - val_loss: 0.0209
# Epoch 42/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0290 - val_loss: 0.0231
# Epoch 43/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0282 - val_loss: 0.0333
# Epoch 44/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0239 - val_loss: 0.0675
# Epoch 45/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0224 - val_loss: 0.0985
# Epoch 46/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0340 - val_loss: 0.0794
# Epoch 47/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0266 - val_loss: 0.0519
# Epoch 48/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0291 - val_loss: 0.0401
# Epoch 49/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0199 - val_loss: 0.0329
# Epoch 50/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0204 - val_loss: 0.0246
# Epoch 51/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0231 - val_loss: 0.0196
# Epoch 52/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0222 - val_loss: 0.0195
# Epoch 53/500
# 1/1 [==============================] - 0s 185ms/step - loss: 0.0245 - val_loss: 0.0196
# Epoch 54/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0248 - val_loss: 0.0191
# Epoch 55/500
# 1/1 [==============================] - 0s 96ms/step - loss: 0.0210 - val_loss: 0.0218
# Epoch 56/500
# 1/1 [==============================] - 0s 107ms/step - loss: 0.0201 - val_loss: 0.0265
# Epoch 57/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0195 - val_loss: 0.0291
# Epoch 58/500
# 1/1 [==============================] - 0s 116ms/step - loss: 0.0181 - val_loss: 0.0311
# Epoch 59/500
# 1/1 [==============================] - 0s 91ms/step - loss: 0.0213 - val_loss: 0.0353
# Epoch 60/500
# 1/1 [==============================] - 0s 94ms/step - loss: 0.0199 - val_loss: 0.0372
# Epoch 61/500
# 1/1 [==============================] - 0s 85ms/step - loss: 0.0207 - val_loss: 0.0311
# Epoch 62/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0189 - val_loss: 0.0237
# Epoch 63/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0182 - val_loss: 0.0205
# Epoch 64/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0189 - val_loss: 0.0196
# Epoch 65/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0183 - val_loss: 0.0193
# Epoch 66/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0194 - val_loss: 0.0191
# Epoch 67/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0192 - val_loss: 0.0190
# Epoch 68/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0185 - val_loss: 0.0195
# Epoch 69/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0186 - val_loss: 0.0215
# Epoch 70/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0177 - val_loss: 0.0249
# Epoch 71/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0180 - val_loss: 0.0269
# Epoch 72/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0182 - val_loss: 0.0263
# Epoch 73/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0182 - val_loss: 0.0254
# Epoch 74/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0185 - val_loss: 0.0252
# Epoch 75/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0178 - val_loss: 0.0242
# Epoch 76/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0180 - val_loss: 0.0218
# Epoch 77/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0176 - val_loss: 0.0199
# Epoch 78/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0178 - val_loss: 0.0193
# Epoch 79/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0180 - val_loss: 0.0194
# Epoch 80/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0178 - val_loss: 0.0198
# Epoch 81/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0180 - val_loss: 0.0201
# Epoch 82/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0177 - val_loss: 0.0205
# Epoch 83/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0177 - val_loss: 0.0215
# Epoch 84/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0176 - val_loss: 0.0229
# Epoch 85/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0176 - val_loss: 0.0236
# Epoch 86/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0178 - val_loss: 0.0230
# Epoch 87/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0176 - val_loss: 0.0221
# Epoch 88/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0177 - val_loss: 0.0216
# Epoch 89/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0175 - val_loss: 0.0211
# Epoch 90/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0176 - val_loss: 0.0204
# Epoch 91/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0175 - val_loss: 0.0197
# Epoch 92/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0176 - val_loss: 0.0195
# Epoch 93/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0176 - val_loss: 0.0199
# Epoch 94/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0175 - val_loss: 0.0204
# Epoch 95/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0175 - val_loss: 0.0207
# Epoch 96/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0175 - val_loss: 0.0209
# Epoch 97/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0175 - val_loss: 0.0214
# Epoch 98/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0175 - val_loss: 0.0218
# Epoch 99/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0175 - val_loss: 0.0217
# Epoch 100/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0175 - val_loss: 0.0211
# Epoch 101/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0175 - val_loss: 0.0206
# Epoch 102/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0175 - val_loss: 0.0204
# Epoch 103/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0175 - val_loss: 0.0202
# Epoch 104/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0175 - val_loss: 0.0199
# Epoch 105/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0175 - val_loss: 0.0198
# Epoch 106/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0175 - val_loss: 0.0200
# Epoch 107/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0174 - val_loss: 0.0203
# Epoch 108/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0205
# Epoch 109/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0206
# Epoch 110/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0174 - val_loss: 0.0207
# Epoch 111/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0174 - val_loss: 0.0208
# Epoch 112/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0174 - val_loss: 0.0206
# Epoch 113/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0174 - val_loss: 0.0203
# Epoch 114/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0200
# Epoch 115/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0199
# Epoch 116/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0174 - val_loss: 0.0199
# Epoch 117/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0198
# Epoch 118/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0174 - val_loss: 0.0198
# Epoch 119/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0199
# Epoch 120/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 121/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 122/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 123/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0201
# Epoch 124/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0174 - val_loss: 0.0200
# Epoch 125/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0174 - val_loss: 0.0199
# Epoch 126/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0174 - val_loss: 0.0197
# Epoch 127/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 128/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 129/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 130/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 131/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 132/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0197
# Epoch 133/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0174 - val_loss: 0.0197
# Epoch 134/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0174 - val_loss: 0.0197
# Epoch 135/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 136/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0196
# Epoch 137/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0195
# Epoch 138/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 139/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 140/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0174 - val_loss: 0.0193
# Epoch 141/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0174 - val_loss: 0.0194
# Epoch 142/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0173 - val_loss: 0.0193
# Epoch 143/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 144/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 145/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 146/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0173 - val_loss: 0.0194
# Epoch 147/500
# 1/1 [==============================] - 0s 54ms/step - loss: 0.0173 - val_loss: 0.0193
# Epoch 148/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0173 - val_loss: 0.0193
# Epoch 149/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0192
# Epoch 150/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0192
# Epoch 151/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 152/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 153/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 154/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 155/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 156/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 157/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 158/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0191
# Epoch 159/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0190
# Epoch 160/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0190
# Epoch 161/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0173 - val_loss: 0.0190
# Epoch 162/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 163/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 164/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 165/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 166/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 167/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 168/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 169/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0173 - val_loss: 0.0189
# Epoch 170/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 171/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 172/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 173/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 174/500
# 1/1 [==============================] - 0s 89ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 175/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 176/500
# 1/1 [==============================] - 0s 86ms/step - loss: 0.0173 - val_loss: 0.0188
# Epoch 177/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 178/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 179/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 180/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 181/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 182/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 183/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 184/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 185/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 186/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 187/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 188/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 189/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 190/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 191/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0173 - val_loss: 0.0186
# Epoch 192/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 193/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 194/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 195/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 196/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 197/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 198/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 199/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 200/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 201/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 202/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 203/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 204/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 205/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 206/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 207/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 208/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 209/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 210/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 211/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 212/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 213/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 214/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 215/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 216/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0173 - val_loss: 0.0184
# Epoch 217/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 218/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 219/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 220/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 221/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 222/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 223/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 224/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 225/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 226/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 227/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 228/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 229/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 230/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 231/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 232/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 233/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 234/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 235/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 236/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 237/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 238/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 239/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 240/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 241/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 242/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 243/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 244/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 245/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 246/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 247/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 248/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 249/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 250/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 251/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 252/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 253/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 254/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 255/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 256/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 257/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 258/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 259/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 260/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 261/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 262/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 263/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 264/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 265/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 266/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 267/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 268/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 269/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 270/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 271/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 272/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 273/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 274/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 275/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 276/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 277/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 278/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 279/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 280/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 281/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 282/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 283/500
# 1/1 [==============================] - 0s 77ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 284/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 285/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 286/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 287/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 288/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 289/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 290/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 291/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 292/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 293/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 294/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 295/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 296/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 297/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 298/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 299/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 300/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 301/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 302/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 303/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 304/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 305/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 306/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 307/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 308/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 309/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 310/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 311/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 312/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 313/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 314/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 315/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 316/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 317/500
# 1/1 [==============================] - 0s 56ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 318/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 319/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 320/500
# 1/1 [==============================] - 0s 55ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 321/500
# 1/1 [==============================] - 0s 53ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 322/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 323/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 324/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 325/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 326/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 327/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 328/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 329/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 330/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 331/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 332/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 333/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 334/500
# 1/1 [==============================] - 0s 57ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 335/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0172 - val_loss: 0.0182
# Epoch 336/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 337/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 338/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 339/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 340/500
# 1/1 [==============================] - 0s 90ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 341/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 342/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 343/500
# 1/1 [==============================] - 0s 84ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 344/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 345/500
# 1/1 [==============================] - 0s 78ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 346/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 347/500
# 1/1 [==============================] - 0s 79ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 348/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 349/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 350/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 351/500
# 1/1 [==============================] - 0s 82ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 352/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 353/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 354/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 355/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 356/500
# 1/1 [==============================] - 0s 81ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 357/500
# 1/1 [==============================] - 0s 80ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 358/500
# 1/1 [==============================] - 0s 87ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 359/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 360/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 361/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 362/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 363/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 364/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 365/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 366/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 367/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 368/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 369/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 370/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 371/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 372/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 373/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 374/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 375/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 376/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 377/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 378/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 379/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 380/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 381/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 382/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 383/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 384/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 385/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 386/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 387/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 388/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 389/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 390/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 391/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 392/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 393/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 394/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 395/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 396/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 397/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 398/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 399/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 400/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 401/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 402/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 403/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 404/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 405/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 406/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 407/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 408/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 409/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0171 - val_loss: 0.0184
# Epoch 410/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0171 - val_loss: 0.0183
# Epoch 411/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0171 - val_loss: 0.0185
# Epoch 412/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0171 - val_loss: 0.0182
# Epoch 413/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0186
# Epoch 414/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0173 - val_loss: 0.0180
# Epoch 415/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0176 - val_loss: 0.0192
# Epoch 416/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0187 - val_loss: 0.0175
# Epoch 417/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0213 - val_loss: 0.0204
# Epoch 418/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0286 - val_loss: 0.0182
# Epoch 419/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0385 - val_loss: 0.0186
# Epoch 420/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0453 - val_loss: 0.0193
# Epoch 421/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0241 - val_loss: 0.0197
# Epoch 422/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0263 - val_loss: 0.0181
# Epoch 423/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0343 - val_loss: 0.0176
# Epoch 424/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0183 - val_loss: 0.0190
# Epoch 425/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0252 - val_loss: 0.0310
# Epoch 426/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0340 - val_loss: 0.0195
# Epoch 427/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0195 - val_loss: 0.0175
# Epoch 428/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0222 - val_loss: 0.0182
# Epoch 429/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0239 - val_loss: 0.0171
# Epoch 430/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0196 - val_loss: 0.0173
# Epoch 431/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0237 - val_loss: 0.0178
# Epoch 432/500
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0175 - val_loss: 0.0221
# Epoch 433/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0227 - val_loss: 0.0195
# Epoch 434/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0180 - val_loss: 0.0181
# Epoch 435/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0208 - val_loss: 0.0186
# Epoch 436/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0188 - val_loss: 0.0173
# Epoch 437/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0190 - val_loss: 0.0168
# Epoch 438/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0191 - val_loss: 0.0168
# Epoch 439/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0186 - val_loss: 0.0168
# Epoch 440/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0188 - val_loss: 0.0171
# Epoch 441/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0180 - val_loss: 0.0169
# Epoch 442/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0189 - val_loss: 0.0172
# Epoch 443/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0177 - val_loss: 0.0176
# Epoch 444/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0187 - val_loss: 0.0168
# Epoch 445/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0174 - val_loss: 0.0167
# Epoch 446/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0185 - val_loss: 0.0166
# Epoch 447/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0175 - val_loss: 0.0167
# Epoch 448/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0183 - val_loss: 0.0168
# Epoch 449/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 450/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0181 - val_loss: 0.0176
# Epoch 451/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0174 - val_loss: 0.0181
# Epoch 452/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0180 - val_loss: 0.0174
# Epoch 453/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0170
# Epoch 454/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0178 - val_loss: 0.0171
# Epoch 455/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0173
# Epoch 456/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0177 - val_loss: 0.0173
# Epoch 457/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0176
# Epoch 458/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0176 - val_loss: 0.0183
# Epoch 459/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 460/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0175 - val_loss: 0.0181
# Epoch 461/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0177
# Epoch 462/500
# 1/1 [==============================] - 0s 71ms/step - loss: 0.0174 - val_loss: 0.0177
# Epoch 463/500
# 1/1 [==============================] - 0s 70ms/step - loss: 0.0173 - val_loss: 0.0177
# Epoch 464/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0174 - val_loss: 0.0176
# Epoch 465/500
# 1/1 [==============================] - 0s 75ms/step - loss: 0.0173 - val_loss: 0.0178
# Epoch 466/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0173 - val_loss: 0.0183
# Epoch 467/500
# 1/1 [==============================] - 0s 73ms/step - loss: 0.0173 - val_loss: 0.0185
# Epoch 468/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0182
# Epoch 469/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0173 - val_loss: 0.0180
# Epoch 470/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0181
# Epoch 471/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0173 - val_loss: 0.0179
# Epoch 472/500
# 1/1 [==============================] - 0s 67ms/step - loss: 0.0172 - val_loss: 0.0178
# Epoch 473/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0173 - val_loss: 0.0180
# Epoch 474/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0184
# Epoch 475/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 476/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0184
# Epoch 477/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 478/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 479/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 480/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0172 - val_loss: 0.0183
# Epoch 481/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 482/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 483/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 484/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 485/500
# 1/1 [==============================] - 0s 65ms/step - loss: 0.0172 - val_loss: 0.0189
# Epoch 486/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 487/500
# 1/1 [==============================] - 0s 68ms/step - loss: 0.0172 - val_loss: 0.0186
# Epoch 488/500
# 1/1 [==============================] - 0s 69ms/step - loss: 0.0172 - val_loss: 0.0186
# Epoch 489/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 490/500
# 1/1 [==============================] - 0s 59ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 491/500
# 1/1 [==============================] - 0s 58ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 492/500
# 1/1 [==============================] - 0s 62ms/step - loss: 0.0172 - val_loss: 0.0189
# Epoch 493/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0189
# Epoch 494/500
# 1/1 [==============================] - 0s 60ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 495/500
# 1/1 [==============================] - 0s 64ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 496/500
# 1/1 [==============================] - 0s 66ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 497/500
# 1/1 [==============================] - 0s 76ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 498/500
# 1/1 [==============================] - 0s 63ms/step - loss: 0.0172 - val_loss: 0.0187
# Epoch 499/500
# 1/1 [==============================] - 0s 74ms/step - loss: 0.0172 - val_loss: 0.0188
# Epoch 500/500
# 1/1 [==============================] - 0s 61ms/step - loss: 0.0172 - val_loss: 0.0189

# %%
fig_ANN, (ax1_ANN) = plt.subplots(1,1)

ax1_ANN.plot(history.history['loss'])
ax1_ANN.plot(history.history['val_loss'])
ax1_ANN.set_title('Training and testing loss')
ax1_ANN.set_ylabel('loss')
ax1_ANN.set_xlabel('epoch')
ax1_ANN.legend(['training', 'validation'], loc='upper right')
#ax1_ANN.grid(True, color='gray', linestyle='-')
ax1_ANN.set_xlim([0, 1000])
ax1_ANN.set_ylim([0, 1])
# Out:
# (0.0, 1.0)

# %%
Y_data_ANNpred_scaled = history.model.predict(X_data_scaled)
Y_data_ANNpred = scaler_y.inverse_transform(Y_data_ANNpred_scaled)
Y_data_ANNpred_scaled = Y_data_ANNpred_scaled.reshape(n_cases,1,1)
Y_data_ANNpred = Y_data_ANNpred.reshape(n_cases,1,1)
# Out:
# 1/1 [==============================] - 0s 357ms/step

# %%
fig_ANN, (ax1_ANN, ax2_ANN) = plt.subplots(1,2)

cases = np.arange(1, n_cases+1, 1)
ax1_ANN.plot(cases, Y_data_scaled[:,0,:], 'o', markersize=10, color='black', label="testing points") # show training data
ax1_ANN.plot(cases, Y_data_ANNpred_scaled[:,0,:], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax1_ANN.set_ylabel('$K$')
ax1_ANN.set_xlabel('$cases$')


ax2_ANN.plot(cases, Y_data[:,0,:], 'o', markersize=10, color='black', label="testing points") # show training data
ax2_ANN.plot(cases, Y_data_ANNpred[:,0,:], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
ax2_ANN.set_ylabel('$K$')
ax2_ANN.set_xlabel('$cases$')

# ax2_ANN.plot(Y_data[:,1,:], Y_data[:,0,:], 'o', markersize=10, color='gray', label="training points") # show training data
# ax2_ANN.plot(Y_data_ANNpred[:,1], Y_data_ANNpred[:,0], marker='*', linestyle='none', color='red', label="Neural Network prediction") # plot prediction
# ax2_ANN.set_ylabel('$K$')
# ax2_ANN.set_xlabel('$n$')
# # ax2_ANN.legend(loc='best')
# ax2_ANN.set_xlim([0, 0.4])
# ax2_ANN.set_ylim([200, 1800])
#ax2_ANN.grid(True, color='gray', linestyle='-')
# Create figure with specified size
fig_ANN.set_size_inches(22, 8)
